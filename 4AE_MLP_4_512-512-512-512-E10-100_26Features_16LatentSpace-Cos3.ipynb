# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader, Dataset, ConcatDataset
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

# Calculo de similaridade
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
from scipy.spatial.distance import euclidean
from scipy.spatial.distance import cityblock
from sklearn.metrics import jaccard_score

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns

# Define seed
SEED = 42

# Set the seed for reproducibility
torch.manual_seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)  # For multi-GPU setups
torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
torch.backends.cudnn.benchmark = False    # Disable if you want deterministic results

Feature_ambos = [
                #'L4_SRC_PORT',
                #'L4_DST_PORT',
                'PROTOCOL',
                #'L7_PROTO',
                'IN_BYTES',
                'IN_PKTS',
                'OUT_BYTES',
                'OUT_PKTS',
                #'TCP_FLAGS',
                #'CLIENT_TCP_FLAGS',
                #'SERVER_TCP_FLAGS',
                'FLOW_DURATION_MILLISECONDS',
                'DURATION_IN', 
                'DURATION_OUT',
                #'MIN_TTL', 
                #'MAX_TTL',
                'LONGEST_FLOW_PKT',
                #'SHORTEST_FLOW_PKT',
                #'MIN_IP_PKT_LEN', 
                'MAX_IP_PKT_LEN', 
                'SRC_TO_DST_SECOND_BYTES', 
                'DST_TO_SRC_SECOND_BYTES',
                'RETRANSMITTED_IN_BYTES', 
                'RETRANSMITTED_IN_PKTS', 
                'RETRANSMITTED_OUT_BYTES', 
                'RETRANSMITTED_OUT_PKTS',
                'SRC_TO_DST_AVG_THROUGHPUT', 
                'DST_TO_SRC_AVG_THROUGHPUT', 
                'NUM_PKTS_UP_TO_128_BYTES',
                'NUM_PKTS_128_TO_256_BYTES', 
                'NUM_PKTS_256_TO_512_BYTES', 
                'NUM_PKTS_512_TO_1024_BYTES',
                'NUM_PKTS_1024_TO_1514_BYTES', 
                #'TCP_WIN_MAX_IN', 
                #'TCP_WIN_MAX_OUT', 
                'ICMP_TYPE', 
                'ICMP_IPV4_TYPE',
                #'DNS_QUERY_ID', 
                'DNS_QUERY_TYPE', 
                #'DNS_TTL_ANSWER',
                #'FTP_COMMAND_RET_CODE',
                'Label', 
                'Attack']

Feature_name = [f for f in Feature_ambos if f not in ['Label', 'Attack']]

input_dim = 26

# Mapear todos os ataques
map_attacks = {'Benign':0, 
              'DoS':1,
              'dos':1,
              'Reconnaissance':2,
              'DDoS':3,
              'ddos':3,
              'Theft':4,
              'ransomware':5,
              'scanning':6,
              'xss':7,
              'mitm':8,
              'password':9,
              'Backdoor':10,
              'backdoor':10,
              'Analysis':11,
              'Generic':12,
              'Exploits':13,
              'Bot':14,
              'DoS_attacks-SlowHTTPTest':15,
              'SSH-Bruteforce':16,
              'DoS_attacks-Hulk':17,
              'Infilteration':18,
              'DDOS_attack-HOIC':19, 
              'FTP-BruteForce':20,
              'Brute_Force_-Web':21, 
              'DDoS_attacks-LOIC-HTTP':22, 
              'DoS_attacks-GoldenEye':23,
              'DDOS_attack-LOIC-UDP':24, 
              'DoS_attacks-Slowloris':25, 
              'Brute_Force_-XSS':26,
              'SQL_Injection':27
              }

# %%
class AE(nn.Module):
    def __init__(self, input_dim, latent_dim, dropout_rate):
        super(AE, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(512, 256), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(256, 128), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(128, 64), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(64,32), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(32, latent_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 32), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(32, 64), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(64, 128), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(128, 256), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(256, 512), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(512, input_dim)
        )

    def forward(self, x):
        x_enc = self.encoder(x)
        recon = self.decoder(x_enc)
        return recon, x_enc

# %%
def ae_loss(recon_x, x):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    return recon_loss

# %%
class MLP(nn.Module):
    def __init__(self, latent_dim):
        super(MLP, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(latent_dim, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(256, 64),
            nn.ReLU(True),
            nn.Dropout(0.2),

            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.mlp(x)

# %%
def get_datasets(dataset):
    
    if dataset == "dataset1":
         df = pd.read_csv('datasets/dataset1v2.csv') # NF-BoT-IoT-v2
    if dataset == "dataset2":
         df = pd.read_csv('datasets/dataset2v2.csv') # NF-ToN-IoT-v2
    if dataset == "dataset3":
         df = pd.read_csv('datasets/dataset3v2.csv') # NF-UNSW-NB15-v2
    if dataset == "dataset4":
         df = pd.read_csv('datasets/dataset4v2.csv') # NF-CICIDS2018-v3

    dataframe = df[Feature_ambos]
    
    return dataframe

# %%
def preprocessing_data(df):
    df_split = df.copy()
    df_split_label = df_split['Attack']
    df_split = df_split.drop('Attack',axis=1)
    df_split = df_split.drop('Label',axis=1)
    
    # Inicializando o MinMaxScaler (intervalo padrão é [0, 1])
    scaler = MinMaxScaler()

    # Ajustando e transformando os dados
    df_split = scaler.fit_transform(df_split)
    
    df_split_label = df_split_label.to_frame()
    x_split_train, x_split_temp, y_split_train, y_split_temp = train_test_split(df_split, df_split_label, test_size = 0.30, stratify=df_split_label)
    x_split_test, x_split_val, y_split_test, y_split_val = train_test_split(x_split_temp, y_split_temp, test_size = 0.50, stratify=y_split_temp)
    y_split_train['Attack'] = y_split_train['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    z_split_test = y_split_test.copy()
    y_split_test['Attack'] = y_split_test['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    #print(z_split_test)
    z_split_test['Attack']=z_split_test['Attack'].map(map_attacks)
    #z_test = torch.tensor(np.array(z_split_test, dtype=np.float32), dtype = torch.float)
    class_test = torch.tensor(np.array(y_split_test, dtype=np.float32), dtype = torch.float)
    class_attack = torch.tensor(np.array(z_split_test, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(class_attack, class_test)
    z_test = torch.utils.data.DataLoader(dataset, batch_size=100)
    #print(z_split_test)
    y_split_val['Attack'] = y_split_val['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    return x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_test

# %%
def tensor_data(x_source1_train, y_source1_train):
    previsores_train = torch.tensor(np.array(x_source1_train), dtype = torch.float)
    class_train = torch.tensor(np.array(y_source1_train, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(previsores_train, class_train)
    train_loader = torch.utils.data.DataLoader(dataset, batch_size=100, shuffle=True)
    return previsores_train, class_train, dataset, train_loader

# %%
def inicia_datasets(treino):
      df = get_datasets(treino)
      print(f"Prepara {treino}: {df.shape}")
      x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_split_test = preprocessing_data(df)
      print( x_split_train.shape, y_split_train.shape)
      print( x_split_val.shape, y_split_val.shape)
      print( x_split_test.shape, y_split_test.shape)
      dataset_train, class_train, dataset_train, loader_train = tensor_data( x_split_train,  y_split_train)
      dataset_val, class_val, dataset_val, loader_val = tensor_data( x_split_val,  y_split_val)
      dataset_test, class_test, dataset_test, loader_test = tensor_data( x_split_test,  y_split_test)
      return dataset_train, class_train, dataset_train, loader_train, dataset_val, class_val, dataset_val, loader_val, dataset_test, class_test, dataset_test, loader_test, z_split_test

# %%
dataset = "dataset1" 
dataset_train1, class_train1, dataset_train1, loader_train1, dataset_val1, class_val1, dataset_val1, loader_val1, dataset_test1, class_test1, dataset_test1, loader_test1, z_split_test1 = inicia_datasets(dataset)
dataset = "dataset2" 
dataset_train2, class_train2, dataset_train2, loader_train2, dataset_val2, class_val2, dataset_val2, loader_val2, dataset_test2, class_test2, dataset_test2, loader_test2, z_split_test2 = inicia_datasets(dataset)
dataset = "dataset3" 
dataset_train3, class_train3, dataset_train3, loader_train3, dataset_val3, class_val3, dataset_val3, loader_val3, dataset_test3, class_test3, dataset_test3, loader_test3, z_split_test3 = inicia_datasets(dataset)
dataset = "dataset4" 
dataset_train4, class_train4, dataset_train4, loader_train4, dataset_val4, class_val4, dataset_val4, loader_val4, dataset_test4, class_test4, dataset_test4, loader_test4, z_split_test4 = inicia_datasets(dataset)

# Gerar ambos para teste e validação
test_dataset_combined = ConcatDataset([dataset_test1, dataset_test2, dataset_test3, dataset_test4])
test_loader_combined = DataLoader(test_dataset_combined, batch_size=loader_test1.batch_size, shuffle=True)
val_dataset_combined = ConcatDataset([dataset_val1, dataset_val2, dataset_val3, dataset_val4])
val_loader_combined = DataLoader(val_dataset_combined, batch_size=loader_val1.batch_size, shuffle=True)
# Out:
# Prepara dataset1: (224511, 28)
# (157157, 26) (157157, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset2: (224512, 28)
# (157158, 26) (157158, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset3: (142152, 28)
# (99506, 26) (99506, 1)
# (21323, 26) (21323, 1)
# (21323, 26) (21323, 1)
# Prepara dataset4: (223976, 28)
# (156783, 26) (156783, 1)
# (33597, 26) (33597, 1)
# (33596, 26) (33596, 1)

# %%
def treina_modelo(modelo_AE1, modelo_AE2, modelo_AE3, modelo_AE4, modelo_MLP, input_dim, device):

    from sklearn.metrics import classification_report
    
    # Hiperparâmetros
    num_classes = 2
    epochs = 600
    lr = 0.001

    Alpha = 1.0
    Beta = 1.0
    Gama = 0.7
    
    patience = 50
    best_val_acc = 0
    epochs_no_improve = 0
    best_model_state = None
  
    # Otimizador conjunto
    params = list(modelo_MLP.parameters()) + list(modelo_AE1.parameters()) + list(modelo_AE2.parameters()) + list(modelo_AE3.parameters()) + list(modelo_AE4.parameters())    
    optimizer = torch.optim.Adam(params, lr=lr)

    # Scheduler: reduz o learning rate se a acurácia parar de melhorar
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=10, factor=0.5)

    # Funções de perda
    class_loss_fn = nn.BCEWithLogitsLoss()

    # Histórico
    loss_vals = []
    loss_valsAE = []
    loss_valsAE2 = []
    loss_valsAE3 = []
    loss_valsMLP = []
    val_simC = []
    val_distE = []
    val_distM = []
    val_accuracies = []
    val_losses = []
       
    for epoch in range(epochs):
        
        modelo_AE1.train()
        modelo_AE2.train()
        modelo_AE3.train()
        modelo_AE4.train()
        modelo_MLP.train()
        
        sum_loss_recon = 0.0
        sum_loss_class = 0.0
        n_batches = 0
        epoch_loss_val = []
        epoch_simC = []
        epoch_corr = []
        epoch_distE = []
        epoch_distM = []
        epoch_simJ = []
        
        # Variaveis para similaridade
        simC = 0  # Cosseno 
        corr = 0  # Pearson 1.0 Correlação perfeita
        distE = 0  #  Eculidiana - Distância euclidiana
        distM = 0  # Distância de Manhattan
        simJ = 0  # Similaridade de Jaccard (para vetores binários ou conjuntos)

        for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_train1, loader_train2, loader_train3, loader_train4):
    
            X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
            y = torch.cat([y1, y2, y3, y4], dim=0).to(device).float()
            y = y.view(-1, 1)
            
            optimizer.zero_grad()
            
            # Forward do VAE1
            recon1, x_latent1 = modelo_AE1(X)
            
            # Forward do VAE2
            recon2, x_latent2 = modelo_AE2(X)

            # Forward do VAE3
            recon3, x_latent3 = modelo_AE3(X)

            # Forward do VAE4
            recon4, x_latent4 = modelo_AE4(X)

            
            # Perda de reconstrução (VAE1)
            recon_loss1 = ae_loss(recon1, X)
            
            # Perda de reconstrução (VAE2)
            recon_loss2 = ae_loss(recon2, X)

            # Perda de reconstrução (VAE3)
            recon_loss3 = ae_loss(recon3, X)

            # Perda de reconstrução (VAE4)
            recon_loss4 = ae_loss(recon4, X)

            
            # Cálculo das dissimilaridades
            cos12 = 1 - F.cosine_similarity(x_latent1, x_latent2).mean()
            cos13 = 1 - F.cosine_similarity(x_latent1, x_latent3).mean()
            cos14 = 1 - F.cosine_similarity(x_latent1, x_latent4).mean()
            cos23 = 1 - F.cosine_similarity(x_latent2, x_latent3).mean()
            cos24 = 1 - F.cosine_similarity(x_latent2, x_latent4).mean()
            cos34 = 1 - F.cosine_similarity(x_latent3, x_latent4).mean()
            loss_diss = (cos12 + cos13 + cos14 + cos23 + cos24 + cos34)/6

            # Classificação com vetor latente
            x_latent = torch.cat([x_latent1, x_latent2, x_latent3, x_latent4], dim=1)
            outputs = modelo_MLP(x_latent)
            loss_class = F.binary_cross_entropy(outputs, y)

            # Perda total
            loss_recon = (recon_loss1 + recon_loss2 + recon_loss3  + recon_loss4)/4
            
            total_loss =  ( loss_recon * Alpha ) + ( loss_class * Beta ) + ( loss_diss * Gama )

            total_loss.backward()
            optimizer.step()

            sum_loss_recon += (recon_loss1.item() + recon_loss2.item() + recon_loss3.item()) / 3
            sum_loss_class += loss_class.item()
            n_batches += 1
            
            torch.cuda.empty_cache()
       
        # === Logs da época ===
        loss_epoch_recon = sum_loss_recon / n_batches
        loss_epoch_class = sum_loss_class / n_batches
        
        loss_valsAE.append(loss_epoch_recon)
        loss_valsMLP.append(loss_epoch_class)
        
        print(f"Epoch {epoch+1:02d}/{epochs} | Recon: {loss_epoch_recon:.4f} | Class: {loss_epoch_class:.4f}")
        # Mostrar a simialridade da útlima instancia por época
        #print(f"Similaridade Média mu1, mu2 - Cosseno: {np.mean(simC)} | Euclidiana: {distE} | Manhattan: {distM}")
        modelo_AE1.eval()
        modelo_AE2.eval()
        modelo_AE3.eval()
        modelo_AE4.eval()
        modelo_MLP.eval()
        all_preds, all_labels = [], []
        
        with torch.no_grad():
            
           for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_val1, loader_val2, loader_val3, loader_val4):
    
               X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
               y = torch.cat([y1, y2, y3, y4], dim=0).to(device).float()
               y = y.view(-1, 1)
            
               optimizer.zero_grad()
            
               # Forward do VAE1, VAE2 e VAE3
               recon1, x_latent1 = modelo_AE1(X)
               recon2, x_latent2 = modelo_AE2(X)
               recon3, x_latent3 = modelo_AE3(X)
               recon4, x_latent4 = modelo_AE4(X)
            
               # Classificação com vetor latente
               x_latent = torch.cat([x_latent1, x_latent2, x_latent3, x_latent4], dim=1)
               outputs = modelo_MLP(x_latent)
               loss_class = F.binary_cross_entropy(outputs, y)
               
               preds = (outputs > 0.5).float()

               # Calcula loss (BCE para binário)
               loss = F.binary_cross_entropy(outputs, y)
               
               epoch_loss_val.append(loss.item())
               
               all_preds.append(preds.cpu())
               all_labels.append(y.cpu())

        all_preds_list = torch.cat(all_preds)
        all_labels_list = torch.cat(all_labels)
        acc = (all_preds_list.view(-1) == all_labels_list.view(-1)).float().mean().item()
        loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
    
        val_accuracies.append(acc)
        val_losses.append(loss_val)
        print(f"Acurácia: {acc}")

        # Atualiza scheduler com base na acurácia de validação
        scheduler.step(acc)

        # Mostra o learning rate atual
        for param_group in optimizer.param_groups:
            current_lr = param_group['lr']
        print(f"Learning Rate atual: {current_lr:.6f}")        

        # Early stopping
        if acc > best_val_acc:
            best_val_acc = acc
            epochs_no_improve = 0
            best_model_state = modelo_MLP.state_dict()
        else:
            epochs_no_improve += 1
            print(f"Sem melhoria na validação por {epochs_no_improve} época(s).")
            if epochs_no_improve >= patience:
                print(f"Early stopping ativado na época {epoch+1}")
                break

    # Restaurar melhor modelo
    if best_model_state is not None:
        modelo_MLP.load_state_dict(best_model_state)
        print("Melhor modelo MLP restaurado com base na menor perda de validação.")  
    
    return  all_preds, all_labels

# %%
# Instanciando o modelo
latent_dim = 16
modelo_AE1 = AE(input_dim,latent_dim,0)
modelo_AE2 = AE(input_dim,latent_dim,0.1)
modelo_AE3 = AE(input_dim,latent_dim,0.2)
modelo_AE4 = AE(input_dim,latent_dim,0.3)
latent_dim = 64
modelo_MLP = MLP(latent_dim)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import time 

start = time.time()
train_preds, train_labels = treina_modelo(modelo_AE1, modelo_AE2, modelo_AE3, modelo_AE4, modelo_MLP, input_dim, device)
end = time.time()
tempo = end - start
print("Tempo de execução: ", tempo)

import psutil
import os

process = psutil.Process(os.getpid())
print("Memória usada (MB):", process.memory_info().rss / 1024**2)
# Out:
# Epoch 01/600 | Recon: 24.4484 | Class: 0.5894
# Acurácia: 0.7073652744293213
# Learning Rate atual: 0.001000
# Epoch 02/600 | Recon: 5.6465 | Class: 0.5008
# Acurácia: 0.7618184685707092
# Learning Rate atual: 0.001000
# Epoch 03/600 | Recon: 4.2113 | Class: 0.4560
# Acurácia: 0.8102732300758362
# Learning Rate atual: 0.001000
# Epoch 04/600 | Recon: 3.7267 | Class: 0.4274
# Acurácia: 0.8075254559516907
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 05/600 | Recon: 3.3867 | Class: 0.4054
# Acurácia: 0.8129625916481018
# Learning Rate atual: 0.001000
# Epoch 06/600 | Recon: 3.1286 | Class: 0.3864
# Acurácia: 0.8311331272125244
# Learning Rate atual: 0.001000
# Epoch 07/600 | Recon: 3.0037 | Class: 0.3691
# Acurácia: 0.8412707448005676
# Learning Rate atual: 0.001000
# Epoch 08/600 | Recon: 2.8696 | Class: 0.3536
# Acurácia: 0.8410252332687378
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 09/600 | Recon: 2.7624 | Class: 0.3418
# Acurácia: 0.8401365876197815
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 10/600 | Recon: 2.6869 | Class: 0.3319
# Acurácia: 0.8720577955245972
# Learning Rate atual: 0.001000
# Epoch 11/600 | Recon: 2.5494 | Class: 0.3267
# Acurácia: 0.8597219586372375
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 12/600 | Recon: 2.5334 | Class: 0.3151
# Acurácia: 0.8500754237174988
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 13/600 | Recon: 2.4611 | Class: 0.3080
# Acurácia: 0.8702337145805359
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 3 época(s).
# Epoch 14/600 | Recon: 2.4493 | Class: 0.2995
# Acurácia: 0.8851186037063599
# Learning Rate atual: 0.001000
# Epoch 15/600 | Recon: 2.4011 | Class: 0.2976
# Acurácia: 0.8854343295097351
# Learning Rate atual: 0.001000
# Epoch 16/600 | Recon: 2.4521 | Class: 0.2965
# Acurácia: 0.8704441785812378
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 17/600 | Recon: 2.2778 | Class: 0.2844
# Acurácia: 0.8882522583007812
# Learning Rate atual: 0.001000
# Epoch 18/600 | Recon: 2.2510 | Class: 0.2786
# Acurácia: 0.8859020471572876
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 19/600 | Recon: 2.3566 | Class: 0.2692
# Acurácia: 0.8696491122245789
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 20/600 | Recon: 2.2226 | Class: 0.2626
# Acurácia: 0.8958759903907776
# Learning Rate atual: 0.001000
# Epoch 21/600 | Recon: 2.1963 | Class: 0.2581
# Acurácia: 0.8712744116783142
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 105/600 | Recon: 1.2130 | Class: 0.1244
# Acurácia: 0.9430562257766724
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 106/600 | Recon: 1.1961 | Class: 0.1239
# Acurácia: 0.9599990844726562
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 107/600 | Recon: 1.2020 | Class: 0.1235
# Acurácia: 0.9600458145141602
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 108/600 | Recon: 1.2094 | Class: 0.1235
# Acurácia: 0.9604784846305847
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 109/600 | Recon: 1.2084 | Class: 0.1220
# Acurácia: 0.8343954086303711
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 7 época(s).
# Epoch 110/600 | Recon: 1.2305 | Class: 0.1226
# Acurácia: 0.9617062211036682
# Learning Rate atual: 0.000250
# Epoch 111/600 | Recon: 1.2288 | Class: 0.1225
# Acurácia: 0.9613437056541443
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 112/600 | Recon: 1.1834 | Class: 0.1232
# Acurácia: 0.9625948667526245
# Learning Rate atual: 0.000250
# Epoch 113/600 | Recon: 1.1774 | Class: 0.1225
# Acurácia: 0.9619400501251221
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 114/600 | Recon: 1.1732 | Class: 0.1223
# Acurácia: 0.9622908234596252
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 115/600 | Recon: 1.1868 | Class: 0.1216
# Acurácia: 0.8339511156082153
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 116/600 | Recon: 1.1826 | Class: 0.1211
# Acurácia: 0.805175244808197
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 117/600 | Recon: 1.1684 | Class: 0.1217
# Acurácia: 0.9617763757705688
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 118/600 | Recon: 1.1546 | Class: 0.1221
# Acurácia: 0.8360674977302551
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 119/600 | Recon: 1.1637 | Class: 0.1222
# Acurácia: 0.9615659117698669
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 7 época(s).
# Epoch 120/600 | Recon: 1.1557 | Class: 0.1214
# Acurácia: 0.9631327390670776
# Learning Rate atual: 0.000250
# Epoch 121/600 | Recon: 1.1666 | Class: 0.1217
# Acurácia: 0.9631210565567017
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 122/600 | Recon: 1.1614 | Class: 0.1205
# Acurácia: 0.9608409404754639
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 123/600 | Recon: 1.1722 | Class: 0.1233
# Acurácia: 0.9436058402061462
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 124/600 | Recon: 1.1655 | Class: 0.1220
# Acurácia: 0.8398208618164062
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 125/600 | Recon: 1.1504 | Class: 0.1213
# Acurácia: 0.8345240354537964
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 126/600 | Recon: 1.1482 | Class: 0.1207
# Acurácia: 0.8400664329528809
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 127/600 | Recon: 1.1801 | Class: 0.1211
# Acurácia: 0.9633198380470276
# Learning Rate atual: 0.000250
# Epoch 128/600 | Recon: 1.1542 | Class: 0.1204
# Acurácia: 0.9330238699913025
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 129/600 | Recon: 1.2942 | Class: 0.1209
# Acurácia: 0.8368859887123108
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 130/600 | Recon: 1.1782 | Class: 0.1215
# Acurácia: 0.9628286957740784
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 131/600 | Recon: 1.1530 | Class: 0.1196
# Acurácia: 0.9628170132637024
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 132/600 | Recon: 1.1359 | Class: 0.1208
# Acurácia: 0.9634250402450562
# Learning Rate atual: 0.000250
# Epoch 133/600 | Recon: 1.1445 | Class: 0.1200
# Acurácia: 0.9642552137374878
# Learning Rate atual: 0.000250
# Epoch 134/600 | Recon: 1.1404 | Class: 0.1199
# Acurácia: 0.9627819657325745
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 135/600 | Recon: 1.1503 | Class: 0.1178
# Acurácia: 0.9455351233482361
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 136/600 | Recon: 1.1590 | Class: 0.1199
# Acurácia: 0.963647186756134
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 137/600 | Recon: 1.1380 | Class: 0.1187
# Acurácia: 0.9618815779685974
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 138/600 | Recon: 1.1371 | Class: 0.1192
# Acurácia: 0.9640798568725586
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 139/600 | Recon: 1.1537 | Class: 0.1199
# Acurácia: 0.8385463356971741
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 140/600 | Recon: 1.1458 | Class: 0.1180
# Acurácia: 0.9642201662063599
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 7 época(s).
# Epoch 141/600 | Recon: 1.1310 | Class: 0.1189
# Acurácia: 0.9637290835380554
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 8 época(s).
# Epoch 142/600 | Recon: 1.1532 | Class: 0.1182
# Acurácia: 0.9533926248550415
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 9 época(s).
# Epoch 143/600 | Recon: 1.1371 | Class: 0.1194
# Acurácia: 0.839855968952179
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 10 época(s).
# Epoch 144/600 | Recon: 1.1733 | Class: 0.1177
# Acurácia: 0.835541307926178
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 11 época(s).
# Epoch 145/600 | Recon: 1.0901 | Class: 0.1155
# Acurácia: 0.964594304561615
# Learning Rate atual: 0.000125
# Epoch 146/600 | Recon: 1.0740 | Class: 0.1135
# Acurácia: 0.9639979600906372
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 147/600 | Recon: 1.0773 | Class: 0.1151
# Acurácia: 0.963822603225708
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 2 época(s).
# Epoch 148/600 | Recon: 1.0712 | Class: 0.1135
# Acurácia: 0.9649685025215149
# Learning Rate atual: 0.000125
# Epoch 149/600 | Recon: 1.0730 | Class: 0.1142
# Acurácia: 0.8426037430763245
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 150/600 | Recon: 1.0695 | Class: 0.1127
# Acurácia: 0.9648866653442383
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 2 época(s).
# Epoch 151/600 | Recon: 1.0640 | Class: 0.1152
# Acurácia: 0.9641032218933105
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 3 época(s).
# Epoch 152/600 | Recon: 1.0525 | Class: 0.1141
# Acurácia: 0.9633198380470276
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 4 época(s).
# Epoch 153/600 | Recon: 1.0613 | Class: 0.1133
# Acurácia: 0.9653075933456421
# Learning Rate atual: 0.000125
# Epoch 154/600 | Recon: 1.0639 | Class: 0.1140
# Acurácia: 0.9642201662063599
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 155/600 | Recon: 1.0723 | Class: 0.1125
# Acurácia: 0.9644072651863098
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 2 época(s).
# Epoch 156/600 | Recon: 1.0681 | Class: 0.1138
# Acurácia: 0.9620920419692993
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 3 época(s).
# Epoch 157/600 | Recon: 1.0654 | Class: 0.1137
# Acurácia: 0.9627936482429504
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 4 época(s).
# Epoch 158/600 | Recon: 1.0522 | Class: 0.1126
# Acurácia: 0.9634718298912048
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 5 época(s).
# Epoch 159/600 | Recon: 1.0605 | Class: 0.1139
# Acurácia: 0.9645241498947144
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 6 época(s).
# Epoch 160/600 | Recon: 1.0485 | Class: 0.1127
# Acurácia: 0.9632145762443542
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 7 época(s).
# Epoch 161/600 | Recon: 1.0679 | Class: 0.1131
# Acurácia: 0.9646527767181396
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 8 época(s).
# Epoch 162/600 | Recon: 1.0466 | Class: 0.1136
# Acurácia: 0.9635185599327087
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 9 época(s).
# Epoch 163/600 | Recon: 1.0530 | Class: 0.1127
# Acurácia: 0.9640564322471619
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 10 época(s).
# Epoch 164/600 | Recon: 1.0514 | Class: 0.1123
# Acurácia: 0.9643721580505371
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 11 época(s).
# Epoch 165/600 | Recon: 1.0314 | Class: 0.1104
# Acurácia: 0.9653777480125427
# Learning Rate atual: 0.000063
# Epoch 166/600 | Recon: 1.0131 | Class: 0.1111
# Acurácia: 0.9655648469924927
# Learning Rate atual: 0.000063
# Epoch 167/600 | Recon: 1.0179 | Class: 0.1109
# Acurácia: 0.9652724862098694
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 168/600 | Recon: 1.0202 | Class: 0.1110
# Acurácia: 0.9650386571884155
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 169/600 | Recon: 1.0276 | Class: 0.1102
# Acurácia: 0.9651906490325928
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 170/600 | Recon: 1.0283 | Class: 0.1114
# Acurácia: 0.9654479026794434
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 171/600 | Recon: 1.0219 | Class: 0.1108
# Acurácia: 0.9656817317008972
# Learning Rate atual: 0.000063
# Epoch 172/600 | Recon: 1.0187 | Class: 0.1099
# Acurácia: 0.9648983478546143
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 173/600 | Recon: 1.0146 | Class: 0.1107
# Acurácia: 0.9659506678581238
# Learning Rate atual: 0.000063
# Epoch 174/600 | Recon: 1.0118 | Class: 0.1109
# Acurácia: 0.9656350016593933
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 175/600 | Recon: 1.0211 | Class: 0.1099
# Acurácia: 0.9651789665222168
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 176/600 | Recon: 1.0158 | Class: 0.1101
# Acurácia: 0.9652724862098694
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 177/600 | Recon: 1.0140 | Class: 0.1102
# Acurácia: 0.9649801850318909
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 178/600 | Recon: 1.0144 | Class: 0.1101
# Acurácia: 0.9651321768760681
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 5 época(s).
# Epoch 179/600 | Recon: 1.0165 | Class: 0.1107
# Acurácia: 0.9664885401725769
# Learning Rate atual: 0.000063
# Epoch 180/600 | Recon: 1.0153 | Class: 0.1100
# Acurácia: 0.9654127955436707
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 181/600 | Recon: 1.0103 | Class: 0.1106
# Acurácia: 0.9652257561683655
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 182/600 | Recon: 1.0225 | Class: 0.1102
# Acurácia: 0.9649217128753662
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 183/600 | Recon: 1.0084 | Class: 0.1102
# Acurácia: 0.9655531048774719
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 184/600 | Recon: 1.0064 | Class: 0.1104
# Acurácia: 0.9658103585243225
# Learning Rate atual: 0.000063
# Sem melhoria na validação por
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 9 época(s).
# Epoch 213/600 | Recon: 0.9795 | Class: 0.1086
# Acurácia: 0.9662430286407471
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 10 época(s).
# Epoch 214/600 | Recon: 0.9840 | Class: 0.1076
# Acurácia: 0.9649918675422668
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 11 época(s).
# Epoch 215/600 | Recon: 0.9795 | Class: 0.1084
# Acurácia: 0.9659039378166199
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 12 época(s).
# Epoch 216/600 | Recon: 0.9787 | Class: 0.1079
# Acurácia: 0.9661728143692017
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 13 época(s).
# Epoch 217/600 | Recon: 0.9833 | Class: 0.1073
# Acurácia: 0.9658805131912231
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 14 época(s).
# Epoch 218/600 | Recon: 0.9739 | Class: 0.1074
# Acurácia: 0.9657518863677979
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 15 época(s).
# Epoch 219/600 | Recon: 0.9747 | Class: 0.1075
# Acurácia: 0.9663482308387756
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 16 época(s).
# Epoch 220/600 | Recon: 0.9791 | Class: 0.1079
# Acurácia: 0.9661494493484497
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 17 época(s).
# Epoch 221/600 | Recon: 0.9795 | Class: 0.1080
# Acurácia: 0.9668276309967041
# Learning Rate atual: 0.000008
# Epoch 222/600 | Recon: 0.9787 | Class: 0.1083
# Acurácia: 0.9658454656600952
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 1 época(s).
# Epoch 223/600 | Recon: 0.9744 | Class: 0.1069
# Acurácia: 0.9656934142112732
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 2 época(s).
# Epoch 224/600 | Recon: 0.9782 | Class: 0.1082
# Acurácia: 0.96552973985672
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 3 época(s).
# Epoch 225/600 | Recon: 0.9727 | Class: 0.1080
# Acurácia: 0.966102659702301
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 4 época(s).
# Epoch 226/600 | Recon: 0.9750 | Class: 0.1071
# Acurácia: 0.9662196040153503
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 5 época(s).
# Epoch 227/600 | Recon: 0.9796 | Class: 0.1079
# Acurácia: 0.9669094681739807
# Learning Rate atual: 0.000004
# Epoch 228/600 | Recon: 0.9671 | Class: 0.1082
# Acurácia: 0.9665938019752502
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 1 época(s).
# Epoch 229/600 | Recon: 0.9769 | Class: 0.1079
# Acurácia: 0.9663365483283997
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 2 época(s).
# Epoch 230/600 | Recon: 0.9800 | Class: 0.1076
# Acurácia: 0.966453492641449
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 3 época(s).
# Epoch 231/600 | Recon: 0.9788 | Class: 0.1079
# Acurácia: 0.9659156203269958
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 4 época(s).
# Epoch 232/600 | Recon: 0.9751 | Class: 0.1079
# Acurácia: 0.9657986760139465
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 5 época(s).
# Epoch 233/600 | Recon: 0.9741 | Class: 0.1075
# Acurácia: 0.96552973985672
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 6 época(s).
# Epoch 234/600 | Recon: 0.9660 | Class: 0.1075
# Acurácia: 0.9657986760139465
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 7 época(s).
# Epoch 235/600 | Recon: 0.9776 | Class: 0.1074
# Acurácia: 0.9661962389945984
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 8 época(s).
# Epoch 236/600 | Recon: 0.9774 | Class: 0.1072
# Acurácia: 0.9653192758560181
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 9 época(s).
# Epoch 237/600 | Recon: 0.9617 | Class: 0.1076
# Acurácia: 0.9661845564842224
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 10 época(s).
# Epoch 238/600 | Recon: 0.9709 | Class: 0.1075
# Acurácia: 0.9654829502105713
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 11 época(s).
# Epoch 239/600 | Recon: 0.9722 | Class: 0.1078
# Acurácia: 0.9664768576622009
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 12 época(s).
# Epoch 240/600 | Recon: 0.9686 | Class: 0.1077
# Acurácia: 0.9654479026794434
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 13 época(s).
# Epoch 241/600 | Recon: 0.9659 | Class: 0.1072
# Acurácia: 0.9657402038574219
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 14 época(s).
# Epoch 242/600 | Recon: 0.9651 | Class: 0.1075
# Acurácia: 0.9663365483283997
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 15 época(s).
# Epoch 243/600 | Recon: 0.9688 | Class: 0.1070
# Acurácia: 0.9664183855056763
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 16 época(s).
# Epoch 244/600 | Recon: 0.9734 | Class: 0.1071
# Acurácia: 0.9660325050354004
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 17 época(s).
# Epoch 245/600 | Recon: 0.9696 | Class: 0.1068
# Acurácia: 0.965330958366394
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 18 época(s).
# Epoch 246/600 | Recon: 0.9745 | Class: 0.1070
# Acurácia: 0.965705156326294
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 19 época(s).
# Epoch 247/600 | Recon: 0.9696 | Class: 0.1070
# Acurácia: 0.9661962389945984
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 20 época(s).
# Epoch 248/600 | Recon: 0.9716 | Class: 0.1077
# Acurácia: 0.9663833379745483
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 21 época(s).
# Epoch 249/600 | Recon: 0.9693 | Class: 0.1069
# Acurácia: 0.9657635688781738
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 22 época(s).
# Epoch 250/600 | Recon: 0.9770 | Class: 0.1068
# Acurácia: 0.9660676121711731
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 23 época(s).
# Epoch 251/600 | Recon: 0.9795 | Class: 0.1076
# Acurácia: 0.9662079215049744
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 24 época(s).
# Epoch 252/600 | Recon: 0.9753 | Class: 0.1082
# Acurácia: 0.966090977191925
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 25 época(s).
# Epoch 253/600 | Recon: 0.9759 | Class: 0.1070
# Acurácia: 0.9662312865257263
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 26 época(s).
# Epoch 254/600 | Recon: 0.9699 | Class: 0.1072
# Acurácia: 0.9661611318588257
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 27 época(s).
# Epoch 255/600 | Recon: 0.9627 | Class: 0.1076
# Acurácia: 0.9659740924835205
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 28 época(s).
# Epoch 256/600 | Recon: 0.9751 | Class: 0.1075
# Acurácia: 0.9660208225250244
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 29 época(s).
# Epoch 257/600 | Recon: 0.9628 | Class: 0.1074
# Acurácia: 0.9657168388366699
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 30 época(s).
# Epoch 258/600 | Recon: 0.9691 | Class: 0.1074
# Acurácia: 0.9653192758560181
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 31 época(s).
# Epoch 259/600 | Recon: 0.9711 | Class: 0.1070
# Acurácia: 0.9660676121711731
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 32 época(s).
# Epoch 260/600 | Recon: 0.9761 | Class: 0.1073
# Acurácia: 0.9659623503684998
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 33 época(s).
# Epoch 261/600 | Recon: 0.9607 | Class: 0.1074
# Acurácia: 0.9660091400146484
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 34 época(s).
# Epoch 262/600 | Recon: 0.9712 | Class: 0.1074
# Acurácia: 0.9657168388366699
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 35 época(s).
# Epoch 263/600 | Recon: 0.9756 | Class: 0.1067
# Acurácia: 0.9661260843276978
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 36 época(s).
# Epoch 264/600 | Recon: 0.9658 | Class: 0.1076
# Acurácia: 0.9664768576622009
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 37 época(s).
# Epoch 265/600 | Recon: 0.9770 | Class: 0.1075
# Acurácia: 0.9660559296607971
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 38 época(s).
# Epoch 266/600 | Recon: 0.9678 | Class: 0.1071
# Acurácia: 0.9658103585243225
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 39 época(s).
# Epoch 267/600 | Recon: 0.9655 | Class: 0.1072
# Acurácia: 0.9665002226829529
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 40 época(s).
# Epoch 268/600 | Recon: 0.9652 | Class: 0.1066
# Acurácia: 0.9656232595443726
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 41 época(s).
# Epoch 269/600 | Recon: 0.9697 | Class: 0.1075
# Acurácia: 0.9665353298187256
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 42 época(s).
# Epoch 270/600 | Recon: 0.9881 | Class: 0.1078
# Acurácia: 0.9661144018173218
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 43 época(s).
# Epoch 271/600 | Recon: 0.9681 | Class: 0.1077
# Acurácia: 0.9660208225250244
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 44 época(s).
# Epoch 272/600 | Recon: 0.9679 | Class: 0.1064
# Acurácia: 0.9659156203269958
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 45 época(s).
# Epoch 273/600 | Recon: 0.9664 | Class: 0.1074
# Acurácia: 0.966254711151123
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 46 época(s).
# Epoch 274/600 | Recon: 0.9811 | Class: 0.1074
# Acurácia: 0.9658220410346985
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 47 época(s).
# Epoch 275/600 | Recon: 0.9665 | Class: 0.1070
# Acurácia: 0.9654595851898193
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 48 época(s).
# Epoch 276/600 | Recon: 0.9734 | Class: 0.1071
# Acurácia: 0.9659506678581238
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 49 época(s).
# Epoch 277/600 | Recon: 0.9731 | Class: 0.1069
# Acurácia: 0.9659857749938965
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 50 época(s).
# Early stopping ativado na época 277
# Melhor modelo MLP restaurado com base na menor perda de validação.
# Tempo de execução:  52739.918256521225
# Memória usada (MB): 2039.4921875

# %%
def testa(target_test, treino, labels_test):
  # Valida source
  modelo_AE1.eval()
  modelo_AE2.eval()
  modelo_AE3.eval()
  modelo_AE4.eval()
  modelo_MLP.eval()
  all_preds, all_labels, all_attacks = [], [], []

  with torch.no_grad():
      
    for (X, y), (z, y2) in zip(target_test, labels_test):

         X = X.to(device)
         y = y.to(device).float()
         y = y.view(-1, 1)
         z = z.to(device).float()
         z = z.view(-1, 1)
            
         # Forward do VAE1, VAE2
         recon1, x_latent1 = modelo_AE1(X)
         recon2, x_latent2 = modelo_AE2(X)
         recon3, x_latent3 = modelo_AE3(X)
         recon4, x_latent4 = modelo_AE4(X)
            
         # Classificação com vetor latente
         x_latent = torch.cat([x_latent1, x_latent2, x_latent3, x_latent4], dim=1)
         outputs = modelo_MLP(x_latent)
         loss_class = F.binary_cross_entropy(outputs, y)
               
         preds = (outputs > 0.5).float()

         # Calcula loss (BCE para binário)
         loss = F.binary_cross_entropy(outputs, y)
               
         all_preds.append(preds.cpu())
         all_labels.append(y.cpu())
         all_attacks.append(z.cpu())
        
  all_preds_list = torch.cat(all_preds)
  all_labels_list = torch.cat(all_labels)
  all_attacks_list = torch.cat(all_attacks)

  acc = (all_preds_list.view(-1) == all_labels_list.view(-1)).float().mean().item()

  # Matriz de confusão
  matriz2 = confusion_matrix(all_preds_list.numpy().round(), all_labels_list.numpy().round())
  sns.set(rc={"figure.figsize": (6, 6)})
  title = "Matriz de Confusão: " + treino
  sns.heatmap(matriz2/np.sum(matriz2), annot=True, annot_kws={'size': 10}, fmt='.2%', cmap='Blues').set_title(title)
  plt.show()

  # Extração dos elementos da matriz (para problema binário)
  TN, FP, FN, TP = matriz2.ravel()

  # Cálculo das métricas
  TPR = TP / (TP + FN) if (TP + FN) != 0 else 0  # Sensibilidade, Recall
  TNR = TN / (TN + FP) if (TN + FP) != 0 else 0  # Especificidade
  F1 = f1_score(all_labels_list.detach().numpy().round(), all_preds_list.detach().numpy().round())
  return TPR, TNR, F1, acc, all_preds_list.view(-1), all_labels_list.view(-1), all_attacks_list.view(-1)

# %%
datasets = ["dataset1", "dataset2", "dataset3", "dataset4"]
target_test = [loader_test1, loader_test2, loader_test3, loader_test4]
labels_test = [z_split_test1, z_split_test2, z_split_test3, z_split_test4]

TPRs = []
TNRs = []
F1s = []
ACCs = []
all_preds_lists = []
all_labels_lists = []
all_attacks_lists = []

for data, teste, labels  in zip(datasets, target_test, labels_test):
    print(f"Treinando com Ambos e validando com {data}")
    TPR, TNR, F1, acc, all_preds_list, all_labels_list, all_attacks_list = testa(teste, data, labels)
    TPRs.append(TPR)
    TNRs.append(TNR)
    F1s.append(F1)
    ACCs.append(acc)
    all_preds_lists.extend(all_preds_list)
    all_labels_lists.extend(all_labels_list)
    all_attacks_lists.extend(all_attacks_list)
    
# Criação da tabela
df = pd.DataFrame({
    'Dataset': datasets,
    'TPR': TPRs,
    'TNR': TNRs,
    'F1-Score': F1s,
    'Acurácia': ACCs
})
print("----------------------------------------------")
print("Resumo da validação nos Datasets:")
print(df)
print("----------------------------------------------")
# Out:
# Treinando com Ambos e validando com dataset1
# Treinando com Ambos e validando com dataset2
# Treinando com Ambos e validando com dataset3
# Treinando com Ambos e validando com dataset4
# ----------------------------------------------
# Resumo da validação nos Datasets:
#     Dataset       TPR       TNR  F1-Score  Acurácia
# 0  dataset1  0.975715  0.971273  0.973420  0.973483
# 1  dataset2  0.916993  0.957171  0.937594  0.936158
# 2  dataset3  0.991425  0.996602  0.994019  0.993997
# 3  dataset4  0.994870  0.928726  0.957923  0.959430
# ----------------------------------------------

# %%
# Combinar todas as predições em um dataframe para tabulação

all_labels = [t.item() for t in all_labels_lists]
all_preds = [t.item() for t in all_preds_lists]
all_attacks = [t.item() for t in all_attacks_lists]

# Inverter dicionario
map_attacks_inv = {v: k for k, v in map_attacks.items()}

df = pd.DataFrame({
    "Real": all_labels,
    "Previsto": all_preds,
    "Ataque": all_attacks
})

# Criar coluna de acerto/erro
df["Acertou"] = df["Real"] == df["Previsto"]

# Agrupar predições por tipo de ataque
tabela = df.groupby("Ataque").agg(
    Total=("Real","count"),
    Acertos=("Acertou","sum")
)

# Adicionar Acurácia por ataque
tabela["Acurácia"] = tabela["Acertos"] / tabela["Total"]

# Adicionar F1 por ataque
f1_por_ataque = {}
TP_por_ataque = {}
TN_por_ataque = {}
FP_por_ataque = {}
FN_por_ataque = {}
for atk, grupo in df.groupby("Ataque"):
    f1_por_ataque[atk] = f1_score(grupo["Real"], grupo["Previsto"], zero_division=0)
    TP_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 1)).sum()
    TN_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 0)).sum()
    FP_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 1)).sum()
    FN_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 0)).sum()

tabela["TP"] = tabela.index.map(TP_por_ataque)
tabela["TN"] = tabela.index.map(TN_por_ataque)
tabela["FP"] = tabela.index.map(FP_por_ataque)
tabela["FN"] = tabela.index.map(FN_por_ataque)
tabela["F1"] = tabela.index.map(f1_por_ataque)


# Renomear indice pelo nome do ataque
tabela.index = tabela.index.map(map_attacks_inv)

print("Resumo por tipo de ataque:")
print(tabela)
# Out:
# Resumo por tipo de ataque:
#                           Total  Acertos  Acurácia     TP     TN    FP    FN  \
# Ataque
# Benign                    61125    58842  0.962650  29370  29472  1012  1271
# dos                        8527     8257  0.968336   4156   4101   152   118
# Reconnaissance             7409     7276  0.982049   3651   3625    68    65
# ddos                       9825     9383  0.955013   4716   4667   270   172
# Theft                       364      349  0.958791    183    166     5    10
# ransomware                  514      476  0.926070    249    227    27    11
# scanning                   2166     2021  0.933056   1018   1003   100    45
# xss                        2167     2015  0.929857   1032    983    94    58
# mitm                       1158     1079  0.931779    506    573    47    32
# password                   2167     2029  0.936317   1029   1000    89    49
# backdoor                   2491     2351  0.943798   1209   1142    98    42
# Analysis                    345      344  0.997101    172    172     0     1
# Generic                    2484     2463  0.991546   1186   1277    20     1
# Exploits                   4733     4708  0.994718   2393   2315    18     7
# Bot                        1650     1593  0.965455    762    831     3    54
# DoS_attacks-SlowHTTPTest   1500     1454  0.969333    727    727     5    41
# SSH-Bruteforce             1650     1571  0.952121    781    790     5    74
# DoS_attacks-Hulk           1500     1454  0.969333    682    772     3    43
# Infilteration              1650     1588  0.962424    745    843     2    60
# DDOS_attack-HOIC           1650     1577  0.955758    776    801     6    67
# FTP-BruteForce             1650     1577  0.955758    743    834     4    69
# Brute_Force_-Web            243      231  0.950617    121    110     0    12
# DDoS_attacks-LOIC-HTTP     1650     1574  0.953939    745    829     5    71
# DoS_attacks-GoldenEye      1500     1443  0.962000    695    748     3    54
# DDOS_attack-LOIC-UDP        517      489  0.945841    246    243     1    27
# DoS_attacks-Slowloris      1500     1458  0.972000    699    759     4    38
# Brute_Force_-XSS             72       71  0.986111     33     38     0     1
# SQL_Injection                66       66  1.000000     30     36     0     0
#
#                                 F1
# Ataque
# Benign                    0.962588
# dos                       0.968539
# Reconnaissance            0.982112
# ddos                      0.955236
# Theft                     0.960630
# ransomware                0.929104
# scanning                  0.933517
# xss                       0.931408
# mitm                      0.927589
# password                  0.937158
# backdoor                  0.945270
# Analysis                  0.997101
# Generic                   0.991224
# Exploits                  0.994804
# Bot                       0.963947
# DoS_attacks-SlowHTTPTest  0.969333
# SSH-Bruteforce            0.951859
# DoS_attacks-Hulk          0.967376
# Infilteration             0.960052
# DDOS_attack-HOIC          0.955077
# FTP-BruteForce            0.953175
# Brute_Force_-Web          0.952756
# DDoS_attacks-LOIC-HTTP    0.951469
# DoS_attacks-GoldenEye     0.960608
# DDOS_attack-LOIC-UDP      0.946154
# DoS_attacks-Slowloris     0.970833
# Brute_Force_-XSS          0.985075
# SQL_Injection             1.000000
