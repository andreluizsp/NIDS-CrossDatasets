# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader, Dataset, ConcatDataset
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

# Calculo de similaridade
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
from scipy.spatial.distance import euclidean
from scipy.spatial.distance import cityblock
from sklearn.metrics import jaccard_score

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns

# Define seed
SEED = 42

# Set the seed for reproducibility
torch.manual_seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)  # For multi-GPU setups
torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
torch.backends.cudnn.benchmark = False    # Disable if you want deterministic results

Feature_ambos = [
                #'L4_SRC_PORT',
                #'L4_DST_PORT',
                'PROTOCOL',
                #'L7_PROTO',
                'IN_BYTES',
                'IN_PKTS',
                'OUT_BYTES',
                'OUT_PKTS',
                #'TCP_FLAGS',
                #'CLIENT_TCP_FLAGS',
                #'SERVER_TCP_FLAGS',
                'FLOW_DURATION_MILLISECONDS',
                'DURATION_IN', 
                'DURATION_OUT',
                #'MIN_TTL', 
                #'MAX_TTL',
                'LONGEST_FLOW_PKT',
                #'SHORTEST_FLOW_PKT',
                #'MIN_IP_PKT_LEN', 
                'MAX_IP_PKT_LEN', 
                'SRC_TO_DST_SECOND_BYTES', 
                'DST_TO_SRC_SECOND_BYTES',
                'RETRANSMITTED_IN_BYTES', 
                'RETRANSMITTED_IN_PKTS', 
                'RETRANSMITTED_OUT_BYTES', 
                'RETRANSMITTED_OUT_PKTS',
                'SRC_TO_DST_AVG_THROUGHPUT', 
                'DST_TO_SRC_AVG_THROUGHPUT', 
                'NUM_PKTS_UP_TO_128_BYTES',
                'NUM_PKTS_128_TO_256_BYTES', 
                'NUM_PKTS_256_TO_512_BYTES', 
                'NUM_PKTS_512_TO_1024_BYTES',
                'NUM_PKTS_1024_TO_1514_BYTES', 
                #'TCP_WIN_MAX_IN', 
                #'TCP_WIN_MAX_OUT', 
                'ICMP_TYPE', 
                'ICMP_IPV4_TYPE',
                #'DNS_QUERY_ID', 
                'DNS_QUERY_TYPE', 
                #'DNS_TTL_ANSWER',
                #'FTP_COMMAND_RET_CODE',
                'Label', 
                'Attack']

Feature_name = [f for f in Feature_ambos if f not in ['Label', 'Attack']]

input_dim = 26

# Mapear todos os ataques
map_attacks = {'Benign':0, 
              'DoS':1,
              'dos':1,
              'Reconnaissance':2,
              'DDoS':3,
              'ddos':3,
              'Theft':4,
              'ransomware':5,
              'scanning':6,
              'xss':7,
              'mitm':8,
              'password':9,
              'Backdoor':10,
              'backdoor':10,
              'Analysis':11,
              'Generic':12,
              'Exploits':13,
              'Bot':14,
              'DoS_attacks-SlowHTTPTest':15,
              'SSH-Bruteforce':16,
              'DoS_attacks-Hulk':17,
              'Infilteration':18,
              'DDOS_attack-HOIC':19, 
              'FTP-BruteForce':20,
              'Brute_Force_-Web':21, 
              'DDoS_attacks-LOIC-HTTP':22, 
              'DoS_attacks-GoldenEye':23,
              'DDOS_attack-LOIC-UDP':24, 
              'DoS_attacks-Slowloris':25, 
              'Brute_Force_-XSS':26,
              'SQL_Injection':27
              }

# %%
class AE1(nn.Module):
    def __init__(self, input_dim, latent_dim=32):
        super(AE1, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512), nn.ReLU(),
            nn.Linear(512, 256), nn.ReLU(),
            nn.Linear(256, 128), nn.ReLU(),
            nn.Linear(128, 64), nn.ReLU(),
            nn.Linear(64, latent_dim), nn.ReLU(),
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64), nn.ReLU(),
            nn.Linear(64, 128), nn.ReLU(),
            nn.Linear(128, 256), nn.ReLU(),
            nn.Linear(256, 512), nn.ReLU(),
            nn.Linear(512, input_dim)
        )

    def forward(self, x):
        x_enc = self.encoder(x)
        recon = self.decoder(x_enc)
        return recon, x_enc

# %%
class AE2(nn.Module):
    def __init__(self, input_dim, latent_dim=32, dropout_rate=0.2):
        super(AE2, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(512, 256), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(256, 128), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(128, 64), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(64, latent_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(64, 128), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(128, 256), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(256, 512), nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(512, input_dim)
        )

    def forward(self, x):
        x_enc = self.encoder(x)
        recon = self.decoder(x_enc)
        return recon, x_enc

# %%
class AE3(nn.Module):
    def __init__(self, input_dim, latent_dim=32):
        super(AE3, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 256), nn.ReLU(),
            nn.Linear(256, 128), nn.ReLU(),
            nn.Linear(128, 64), nn.ReLU(),
            nn.Linear(64, latent_dim), nn.ReLU(),
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64), nn.ReLU(),
            nn.Linear(64, 128), nn.ReLU(),
            nn.Linear(128, 256), nn.ReLU(),
            nn.Linear(256, input_dim)
        )

    def forward(self, x):
        x_enc = self.encoder(x)
        recon = self.decoder(x_enc)
        return recon, x_enc

# %%
def ae_loss(recon_x, x):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    return recon_loss

# %%
class MLP(nn.Module):
    def __init__(self, latent_dim):
        super(MLP, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(latent_dim, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(256, 64),
            nn.ReLU(True),
            nn.Dropout(0.2),

            nn.Linear(64, 28),
            #nn.Softmax()
        )

    def forward(self, x):
        return self.mlp(x)

# %%
def get_datasets(dataset):
    
    if dataset == "dataset1":
         df = pd.read_csv('datasets/dataset1v2.csv') # NF-BoT-IoT-v2
    if dataset == "dataset2":
         df = pd.read_csv('datasets/dataset2v2.csv') # NF-ToN-IoT-v2
    if dataset == "dataset3":
         df = pd.read_csv('datasets/dataset3v2.csv') # NF-UNSW-NB15-v2
    if dataset == "dataset4":
         df = pd.read_csv('datasets/dataset4v2.csv') # NF-CICIDS2018-v3

    dataframe = df[Feature_ambos]
    
    return dataframe

# %%
def preprocessing_data(df):
    df_split = df.copy()
    df_split_label = df_split['Attack']
    df_split = df_split.drop('Attack',axis=1)
    df_split = df_split.drop('Label',axis=1)
    
    # Inicializando o MinMaxScaler (intervalo padrão é [0, 1])
    scaler = MinMaxScaler()

    # Ajustando e transformando os dados
    df_split = scaler.fit_transform(df_split)
    
    df_split_label = df_split_label.to_frame()
    x_split_train, x_split_temp, y_split_train, y_split_temp = train_test_split(df_split, df_split_label, test_size = 0.30, stratify=df_split_label)
    x_split_test, x_split_val, y_split_test, y_split_val = train_test_split(x_split_temp, y_split_temp, test_size = 0.50, stratify=y_split_temp)
    #y_split_train['Attack'] = y_split_train['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    z_split_test = y_split_test.copy()
    #y_split_test['Attack'] = y_split_test['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    #print(z_split_test)
    y_split_train['Attack']=y_split_train['Attack'].map(map_attacks)
    y_split_test['Attack']=y_split_test['Attack'].map(map_attacks)
    y_split_val['Attack']=y_split_val['Attack'].map(map_attacks)
    #z_test = torch.tensor(np.array(z_split_test, dtype=np.float32), dtype = torch.float)
    class_test = torch.tensor(np.array(y_split_test, dtype=np.float32), dtype = torch.float)
    class_attack = torch.tensor(np.array(y_split_test, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(class_attack, class_test)
    z_test = torch.utils.data.DataLoader(dataset, batch_size=100)
    #print(z_split_test)
    #y_split_val['Attack'] = y_split_val['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    return x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_test

# %%
def tensor_data(x_source1_train, y_source1_train):
    previsores_train = torch.tensor(np.array(x_source1_train), dtype = torch.float)
    class_train = torch.tensor(np.array(y_source1_train, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(previsores_train, class_train)
    train_loader = torch.utils.data.DataLoader(dataset, batch_size=100, shuffle=True)
    return previsores_train, class_train, dataset, train_loader

# %%
def inicia_datasets(treino):
      df = get_datasets(treino)
      print(f"Prepara {treino}: {df.shape}")
      x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_split_test = preprocessing_data(df)
      print( x_split_train.shape, y_split_train.shape)
      print( x_split_val.shape, y_split_val.shape)
      print( x_split_test.shape, y_split_test.shape)
      dataset_train, class_train, dataset_train, loader_train = tensor_data( x_split_train,  y_split_train)
      dataset_val, class_val, dataset_val, loader_val = tensor_data( x_split_val,  y_split_val)
      dataset_test, class_test, dataset_test, loader_test = tensor_data( x_split_test,  y_split_test)
      return dataset_train, class_train, dataset_train, loader_train, dataset_val, class_val, dataset_val, loader_val, dataset_test, class_test, dataset_test, loader_test, z_split_test

# %%
dataset = "dataset1" 
dataset_train1, class_train1, dataset_train1, loader_train1, dataset_val1, class_val1, dataset_val1, loader_val1, dataset_test1, class_test1, dataset_test1, loader_test1, z_split_test1 = inicia_datasets(dataset)
dataset = "dataset2" 
dataset_train2, class_train2, dataset_train2, loader_train2, dataset_val2, class_val2, dataset_val2, loader_val2, dataset_test2, class_test2, dataset_test2, loader_test2, z_split_test2 = inicia_datasets(dataset)
dataset = "dataset3" 
dataset_train3, class_train3, dataset_train3, loader_train3, dataset_val3, class_val3, dataset_val3, loader_val3, dataset_test3, class_test3, dataset_test3, loader_test3, z_split_test3 = inicia_datasets(dataset)
dataset = "dataset4" 
dataset_train4, class_train4, dataset_train4, loader_train4, dataset_val4, class_val4, dataset_val4, loader_val4, dataset_test4, class_test4, dataset_test4, loader_test4, z_split_test4 = inicia_datasets(dataset)

# Gerar ambos para teste e validação
test_dataset_combined = ConcatDataset([dataset_test1, dataset_test2, dataset_test3, dataset_test4])
test_loader_combined = DataLoader(test_dataset_combined, batch_size=loader_test1.batch_size, shuffle=True)
val_dataset_combined = ConcatDataset([dataset_val1, dataset_val2, dataset_val3, dataset_val4])
val_loader_combined = DataLoader(val_dataset_combined, batch_size=loader_val1.batch_size, shuffle=True)
# Out:
# Prepara dataset1: (224511, 28)
# (157157, 26) (157157, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset2: (224512, 28)
# (157158, 26) (157158, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset3: (142152, 28)
# (99506, 26) (99506, 1)
# (21323, 26) (21323, 1)
# (21323, 26) (21323, 1)
# Prepara dataset4: (223976, 28)
# (156783, 26) (156783, 1)
# (33597, 26) (33597, 1)
# (33596, 26) (33596, 1)

# %%
def treina_modelo(modelo_AE1, modelo_AE2, modelo_AE3, modelo_MLP, input_dim, device):
    from sklearn.metrics import classification_report
    
    # Hiperparâmetros
    num_classes = 27  # Atualizando para 27 classes
    epochs = 600
    lr = 0.001

    Alpha = 0.2
    Beta = 1
    Gama = 0.2
    
    patience = 50
    best_val_acc = 0
    epochs_no_improve = 0
    best_model_state = None
  
    # Otimizador conjunto
    params = list(modelo_MLP.parameters()) + list(modelo_AE1.parameters()) + list(modelo_AE2.parameters()) + list(modelo_AE3.parameters())    
    optimizer = torch.optim.Adam(params, lr=lr)
    loss_fn = nn.CrossEntropyLoss()

    # Scheduler: reduz o learning rate se a acurácia parar de melhorar
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=10, factor=0.5)

    # Histórico
    loss_vals = []
    loss_valsAE = []
    loss_valsAE2 = []
    loss_valsAE3 = []
    loss_valsMLP = []
    val_simC = []
    val_distE = []
    val_distM = []
    val_accuracies = []
    val_losses = []
    
    dissim_cos_12 = []
    dissim_euc_12 = []

    Z_AE1 = []
    Z_AE2 = []
    
    for epoch in range(epochs):
        
        modelo_AE1.train()
        modelo_AE2.train()
        modelo_AE3.train()
        modelo_MLP.train()
        
        epoch_loss_recon = []
        epoch_loss_class = []
        epoch_loss_val = []
        epoch_simC = []
        epoch_corr = []
        epoch_distE = []
        epoch_distM = []
        epoch_simJ = []
        
        # Variáveis para similaridade
        simC = 0  # Cosseno 
        corr = 0  # Pearson 1.0 Correlação perfeita
        distE = 0  #  Eculidiana - Distância euclidiana
        distM = 0  # Distância de Manhattan
        simJ = 0  # Similaridade de Jaccard (para vetores binários ou conjuntos)

        for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_train1, loader_train2, loader_train3, loader_train4):
    
            X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
            y = torch.cat([y1, y2, y3, y4], dim=0).to(device).long()  # Certifique-se de que y seja long
            y = y.squeeze()  # Garantir que y seja 1D
            
            optimizer.zero_grad()
            
            # Forward do VAE1, VAE2 e VAE3
            recon1, x_latent1 = modelo_AE1(X)
            recon2, x_latent2 = modelo_AE2(X)
            recon3, x_latent3 = modelo_AE3(X)

            # Perda de reconstrução
            recon_loss1 = ae_loss(recon1, X)
            recon_loss2 = ae_loss(recon2, X)
            recon_loss3 = ae_loss(recon3, X)

            # Classificação com vetor latente
            x_latent = torch.cat([x_latent1, x_latent2, x_latent3], dim=1)
            outputs = modelo_MLP(x_latent)

            # Calcular a perda de classificação
            loss_class = loss_fn(outputs, y)  # Passando diretamente o tensor y

            # Perda total
            loss_recon = (recon_loss1 + recon_loss2 + recon_loss3) / 3
            loss_diss = (F.mse_loss(x_latent1, x_latent2))

            total_loss = (loss_recon * Alpha) + (loss_class * Beta) + (loss_diss * Gama)

            total_loss.backward()
            optimizer.step()

            epoch_loss_recon.append(recon_loss1.item())
            epoch_loss_recon.append(recon_loss2.item())
            epoch_loss_recon.append(recon_loss3.item())
            epoch_loss_class.append(loss_class.item())

        # === Logs da época ===
        loss_epoch_recon = sum(epoch_loss_recon) / len(epoch_loss_recon)
        loss_epoch_class = sum(epoch_loss_class) / len(epoch_loss_class)
        
        loss_valsAE.append(loss_epoch_recon)
        loss_valsMLP.append(loss_epoch_class)
        
        print(f"Epoch {epoch+1:02d}/{epochs} | Recon: {loss_epoch_recon:.4f} | Class: {loss_epoch_class:.4f}")
        
        modelo_AE1.eval()
        modelo_AE2.eval()
        modelo_AE3.eval()
        modelo_MLP.eval()
        all_preds, all_labels = [], []
        
        with torch.no_grad():
            
           for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_val1, loader_val2, loader_val3, loader_val4):
    
               X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
               y = torch.cat([y1, y2, y3, y4], dim=0).to(device).long()  # Certifique-se de que y seja long
               y = y.squeeze()  # Garantir que y seja 1D

               optimizer.zero_grad()
            
               # Forward do VAE1, VAE2 e VAE3
               recon1, x_latent1 = modelo_AE1(X)
               recon2, x_latent2 = modelo_AE2(X)
               recon3, x_latent3 = modelo_AE3(X)
            
               # Classificação com vetor latente
               x_latent = torch.cat([x_latent1, x_latent2, x_latent3], dim=1)
               outputs = modelo_MLP(x_latent)
               _, preds = torch.max(outputs, 1)
               
               #epoch_loss_val.append(loss.item())
               
               all_preds.append(preds)
               all_labels.append(y)

        all_preds_list = torch.cat(all_preds)
        all_labels_list = torch.cat(all_labels)
        print(f"Predictions shape: {all_preds_list.shape}")
        print(f"Labels shape: {all_labels_list.shape}")
        
        acc = (all_preds_list.view(-1) == all_labels_list.view(-1)).float().mean().item()
        #loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
    
        val_accuracies.append(acc)
        #val_losses.append(loss_val)
        print(f"Acurácia: {acc}")

        # Atualiza scheduler com base na acurácia de validação
        scheduler.step(acc)

        # Mostra o learning rate atual
        for param_group in optimizer.param_groups:
            current_lr = param_group['lr']
        print(f"Learning Rate atual: {current_lr:.6f}")        

        # Early stopping
        if acc > best_val_acc:
            best_val_acc = acc
            epochs_no_improve = 0
            best_model_state = modelo_MLP.state_dict()
        else:
            epochs_no_improve += 1
            print(f"Sem melhoria na validação por {epochs_no_improve} época(s).")
            if epochs_no_improve >= patience:
                print(f"Early stopping ativado na época {epoch+1}")
                break

    # Restaurar melhor modelo
    if best_model_state is not None:
        modelo_MLP.load_state_dict(best_model_state)
        print("Melhor modelo MLP restaurado com base na menor perda de validação.")  
    
    return  all_preds, all_labels

# %%
# Instanciando o modelo
latent_dim = 96
modelo_AE1 = AE1(input_dim)
modelo_AE2 = AE2(input_dim)
modelo_AE3 = AE3(input_dim)
modelo_MLP = MLP(latent_dim)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import time 

start = time.time()
train_preds, train_labels = treina_modelo(modelo_AE1, modelo_AE2, modelo_AE3, modelo_MLP, input_dim, device)
end = time.time()
tempo = end - start
print("Tempo de execução: ", tempo)

import psutil
import os

process = psutil.Process(os.getpid())
print("Memória usada (MB):", process.memory_info().rss / 1024**2)
# Out:
# Epoch 01/600 | Recon: 15.0228 | Class: 1.2180
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.6857219934463501
# Learning Rate atual: 0.001000
# Epoch 02/600 | Recon: 2.6481 | Class: 0.8019
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7331477999687195
# Learning Rate atual: 0.001000
# Epoch 03/600 | Recon: 1.9717 | Class: 0.7048
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7509675621986389
# Learning Rate atual: 0.001000
# Epoch 04/600 | Recon: 1.6566 | Class: 0.6409
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.786934494972229
# Learning Rate atual: 0.001000
# Epoch 05/600 | Recon: 1.4695 | Class: 0.5990
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7780362963676453
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 06/600 | Recon: 1.3838 | Class: 0.5708
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7849584221839905
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 07/600 | Recon: 1.2775 | Class: 0.5451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8288647532463074
# Learning Rate atual: 0.001000
# Epoch 08/600 | Recon: 1.2340 | Class: 0.5173
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8146346807479858
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 09/600 | Recon: 1.1828 | Class: 0.4908
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8258363008499146
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 10/600 | Recon: 1.1263 | Class: 0.4697
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8148918747901917
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 3 época(s).
# Epoch 11/600 | Recon: 1.1124 | Class: 0.4562
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7403388619422913
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 4 época(s).
# Epoch 12/600 | Recon: 1.0793 | Class: 0.4357
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8128456473350525
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 5 época(s).
# Epoch 13/600 | Recon: 1.0480 | Class: 0.4245
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8416449427604675
# Learning Rate atual: 0.001000
# Epoch 14/600 | Recon: 1.0403 | Class: 0.4134
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8556645512580872
# Learning Rate atual: 0.001000
# Epoch 15/600 | Recon: 1.0269 | Class: 0.4068
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8699180483818054
# Learning Rate atual: 0.001000
# Epoch 16/600 | Recon: 1.0156 | Class: 0.3968
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.838920533657074
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 17/600 | Recon: 0.9782 | Class: 0.3918
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8390725255012512
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 18/600 | Recon: 0.9779 | Class: 0.3857
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8375056982040405
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 3 época(s).
# Epoch 19/600 | Recon: 0.9685 | Class: 0.3791
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.870023250579834
# Learning Rate atual: 0.001000
# Epoch 20/600 | Recon: 0.9640 | Class: 0.3735
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8171719908714294
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 21/600 | Recon: 0.9473 | Class: 0.3733
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8808624744415283
# Learning Rate atual: 0.001000
# Epoch 22/600 | Recon: 0.9238 | Class: 0.3663
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8606339693069458
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 23/600 | Recon: 0.9129 | Class: 0.3626
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7584392428398132
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 24/600 | Recon: 0.9141 | Class: 0.3650
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8780795931816101
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 3 época(s).
# Epoch 25/600 | Recon: 0.9240 | Class: 0.3521
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8786993026733398
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 4 época(s).
# Epoch 26/600 | Recon: 0.9299 | Class: 0.3607
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7131648659706116
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 5 época(s).
# Epoch 27/600 | Recon: 0.9025 | Class: 0.3536
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.87489914894104
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 6 época(s).
# Epoch 28/600 | Recon: 0.8885 | Class: 0.3454
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8663283586502075
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 7 época(s).
# Epoch 29/600 | Recon: 0.8927 | Class: 0.3452
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7848649024963379
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 8 época(s).
# Epoch 30/600 | Recon: 0.8716 | Class: 0.3408
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8423932790756226
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 9 época(s).
# Epoch 31/600 | Recon: 0.8673 | Class: 0.3385
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8366638422012329
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 10 época(s).
# Epoch 32/600 | Recon: 0.8743 | Class: 0.3360
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8781497478485107
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 11 época(s).
# Epoch 33/600 | Recon: 0.7102 | Class: 0.3205
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8876793384552002
# Learning Rate atual: 0.000500
# Epoch 34/600 | Recon: 0.7044 | Class: 0.3168
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8564713597297668
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 1 época(s).
# Epoch 35/600 | Recon: 0.6965 | Class: 0.3164
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8683629035949707
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 2 época(s).
# Epoch 36/600 | Recon: 0.6854 | Class: 0.3146
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7654899954795837
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 3 época(s).
# Epoch 37/600 | Recon: 0.6800 | Class: 0.3132
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.868491530418396
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 4 época(s).
# Epoch 38/600 | Recon: 0.6844 | Class: 0.3113
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7898811101913452
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 5 época(s).
# Epoch 39/600 | Recon: 0.6790 | Class: 0.3125
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8679653406143188
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 6 época(s).
# Epoch 40/600 | Recon: 0.6745 | Class: 0.3090
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8593127131462097
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 7 época(s).
# Epoch 41/600 | Recon: 0.6682 | Class: 0.3098
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7444664239883423
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 8 época(s).
# Epoch 42/600 | Recon: 0.6717 | Class: 0.3081
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7600294947624207
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 9 época(s).
# Epoch 43/600 | Recon: 0.6693 | Class: 0.3064
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8651824593544006
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 10 época(s).
# Epoch 44/600 | Recon: 0.6704 | Class: 0.3075
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8726775050163269
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 11 época(s).
# Epoch 45/600 | Recon: 0.6074 | Class: 0.2964
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8943442106246948
# Learning Rate atual: 0.000250
# Epoch 46/600 | Recon: 0.5984 | Class: 0.2954
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.894683301448822
# Learning Rate atual: 0.000250
# Epoch 47/600 | Recon: 0.5908 | Class: 0.2950
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8671468496322632
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 48/600 | Recon: 0.5859 | Class: 0.2929
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8965775370597839
# Learning Rate atual: 0.000250
# Epoch 49/600 | Recon: 0.5874 | Class: 0.2930
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8652642965316772
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 50/600 | Recon: 0.5840 | Class: 0.2921
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8962267637252808
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 51/600 | Recon: 0.5804 | Class: 0.2929
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8954667448997498
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 52/600 | Recon: 0.5833 | Class: 0.2903
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8977935910224915
# Learning Rate atual: 0.000250
# Epoch 53/600 | Recon: 0.5730 | Class: 0.2923
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8958642482757568
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 54/600 | Recon: 0.5795 | Class: 0.2893
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8972674012184143
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 55/600 | Recon: 0.5816 | Class: 0.2882
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8936309814453125
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 56/600 | Recon: 0.5816 | Class: 0.2885
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8904505372047424
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 57/600 | Recon: 0.5772 | Class: 0.2876
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8973609209060669
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 58/600 | Recon: 0.5736 | Class: 0.2862
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8970452547073364
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 59/600 | Recon: 0.5814 | Class: 0.2853
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.7643207311630249
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 7 época(s).
# Epoch 60/600 | Recon: 0.5688 | Class: 0.2855
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8030237555503845
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 8 época(s).
# Epoch 61/600 | Recon: 0.5722 | Class: 0.2848
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.898658812046051
# Learning Rate atual: 0.000250
# Epoch 62/600 | Recon: 0.5737 | Class: 0.2846
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8943675756454468
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 63/600 | Recon: 0.5687 | Class: 0.2836
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8953731656074524
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 64/600 | Recon: 0.5683 | Class: 0.2840
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8982846736907959
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 65/600 | Recon: 0.5688 | Class: 0.2838
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8981560468673706
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 66/600 | Recon: 0.5634 | Class: 0.2826
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8999918103218079
# Learning Rate atual: 0.000250
# Epoch 67/600 | Recon: 0.5665 | Class: 0.2816
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8781614303588867
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 68/600 | Recon: 0.5649 | Class: 0.2822
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8983899354934692
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 69/600 | Recon: 0.5622 | Class: 0.2802
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8967178463935852
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 70/600 | Recon: 0.5581 | Class: 0.2808
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9004712104797363
# Learning Rate atual: 0.000250
# Epoch 71/600 | Recon: 0.5683 | Class: 0.2800
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9002607464790344
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 72/600 | Recon: 0.5706 | Class: 0.2798
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8995007276535034
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 73/600 | Recon: 0.5609 | Class: 0.2781
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8933386206626892
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 74/600 | Recon: 0.5575 | Class: 0.2780
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9014884829521179
# Learning Rate atual: 0.000250
# Epoch 75/600 | Recon: 0.5574 | Class: 0.2771
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.884884774684906
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 76/600 | Recon: 0.5631 | Class: 0.2763
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9023654460906982
# Learning Rate atual: 0.000250
# Epoch 77/600 | Recon: 0.5599 | Class: 0.2759
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8996760845184326
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 78/600 | Recon: 0.5570 | Class: 0.2763
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8989511728286743
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 79/600 | Recon: 0.5522 | Class: 0.2753
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.898261308670044
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 80/600 | Recon: 0.5562 | Class: 0.2746
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9009155631065369
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 81/600 | Recon: 0.5605 | Class: 0.2724
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8448137044906616
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 82/600 | Recon: 0.5584 | Class: 0.2750
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9010558724403381
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 83/600 | Recon: 0.5493 | Class: 0.2740
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9030202627182007
# Learning Rate atual: 0.000250
# Epoch 84/600 | Recon: 0.5532 | Class: 0.2727
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9039322733879089
# Learning Rate atual: 0.000250
# Epoch 85/600 | Recon: 0.5628 | Class: 0.2721
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8999099731445312
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 86/600 | Recon: 0.5533 | Class: 0.2733
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8979572653770447
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 87/600 | Recon: 0.5485 | Class: 0.2721
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9017691016197205
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 88/600 | Recon: 0.5533 | Class: 0.2715
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9050430655479431
# Learning Rate atual: 0.000250
# Epoch 89/600 | Recon: 0.5622 | Class: 0.2703
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9030085206031799
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 90/600 | Recon: 0.5464 | Class: 0.2707
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9041427373886108
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 91/600 | Recon: 0.5499 | Class: 0.2704
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.878278374671936
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 92/600 | Recon: 0.5529 | Class: 0.2703
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9038387537002563
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 93/600 | Recon: 0.5496 | Class: 0.2713
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8991265296936035
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 94/600 | Recon: 0.5461 | Class: 0.2686
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.903756856918335
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 95/600 | Recon: 0.5436 | Class: 0.2678
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9030553102493286
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 7 época(s).
# Epoch 96/600 | Recon: 0.5459 | Class: 0.2696
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9046922922134399
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 8 época(s).
# Epoch 97/600 | Recon: 0.5462 | Class: 0.2676
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9038036465644836
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 9 época(s).
# Epoch 98/600 | Recon: 0.5492 | Class: 0.2709
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8969166278839111
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 10 época(s).
# Epoch 99/600 | Recon: 0.5427 | Class: 0.2675
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.903148889541626
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 11 época(s).
# Epoch 100/600 | Recon: 0.5206 | Class: 0.2606
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9058732986450195
# Learning Rate atual: 0.000125
# Epoch 101/600 | Recon: 0.5237 | Class: 0.2591
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9049612283706665
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 102/600 | Recon: 0.5196 | Class: 0.2586
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9015586376190186
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 2 época(s).
# Epoch 103/600 | Recon: 0.5124 | Class: 0.2588
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9074751734733582
# Learning Rate atual: 0.000125
# Epoch 104/600 | Recon: 0.5160 | Class: 0.2588
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.906165599822998
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 105/600 | Recon: 0.5160 | Class: 0.2587
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9062825441360474
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 2 época(s).
# Epoch 106/600 | Recon: 0.5137 | Class: 0.2588
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9053471088409424
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 3 época(s).
# Epoch 107/600 | Recon: 0.5119 | Class: 0.2591
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9069840908050537
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 4 época(s).
# Epoch 108/600 | Recon: 0.5087 | Class: 0.2570
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9077557921409607
# Learning Rate atual: 0.000125
# Epoch 109/600 | Recon: 0.5163 | Class: 0.2587
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9058265089988708
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 110/600 | Recon: 0.5071 | Class: 0.2573
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9072062373161316
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 2 época(s).
# Epoch 111/600 | Recon: 0.5078 | Class: 0.2586
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9069840908050537
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 3 época(s).
# Epoch 112/600 | Recon: 0.5123 | Class: 0.2569
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9066566824913025
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 4 época(s).
# Epoch 113/600 | Recon: 0.5076 | Class: 0.2566
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9074167013168335
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 5 época(s).
# Epoch 114/600 | Recon: 0.5073 | Class: 0.2556
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9051483273506165
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 6 época(s).
# Epoch 115/600 | Recon: 0.5103 | Class: 0.2565
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9051015377044678
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 7 época(s).
# Epoch 116/600 | Recon: 0.5085 | Class: 0.2585
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9052769541740417
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 8 época(s).
# Epoch 117/600 | Recon: 0.5078 | Class: 0.2575
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.904668927192688
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 9 época(s).
# Epoch 118/600 | Recon: 0.5119 | Class: 0.2574
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9058148264884949
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 10 época(s).
# Epoch 119/600 | Recon: 0.5107 | Class: 0.2589
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8826046586036682
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 11 época(s).
# Epoch 120/600 | Recon: 0.4925 | Class: 0.2534
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9070425629615784
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 12 época(s).
# Epoch 121/600 | Recon: 0.4978 | Class: 0.2536
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9063175916671753
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 13 época(s).
# Epoch 122/600 | Recon: 0.4932 | Class: 0.2531
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.905604362487793
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 14 época(s).
# Epoch 123/600 | Recon: 0.4900 | Class: 0.2538
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9062474370002747
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 15 época(s).
# Epoch 124/600 | Recon: 0.4917 | Class: 0.2528
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9080715179443359
# Learning Rate atual: 0.000063
# Epoch 125/600 | Recon: 0.4982 | Class: 0.2531
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9071828722953796
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 126/600 | Recon: 0.4946 | Class: 0.2533
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9080130457878113
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 127/600 | Recon: 0.4934 | Class: 0.2522
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9083989262580872
# Learning Rate atual: 0.000063
# Epoch 128/600 | Recon: 0.4898 | Class: 0.2521
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9076389074325562
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 129/600 | Recon: 0.4921 | Class: 0.2518
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9082235097885132
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 130/600 | Recon: 0.4938 | Class: 0.2528
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9074167013168335
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 131/600 | Recon: 0.4918 | Class: 0.2517
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9026928544044495
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 132/600 | Recon: 0.4901 | Class: 0.2503
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9067502021789551
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 5 época(s).
# Epoch 133/600 | Recon: 0.4883 | Class: 0.2512
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9079428911209106
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 6 época(s).
# Epoch 134/600 | Recon: 0.4899 | Class: 0.2506
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9057914018630981
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 7 época(s).
# Epoch 135/600 | Recon: 0.4891 | Class: 0.2497
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.8984951376914978
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 8 época(s).
# Epoch 136/600 | Recon: 0.4936 | Class: 0.2506
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9074751734733582
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 9 época(s).
# Epoch 137/600 | Recon: 0.4853 | Class: 0.2514
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.904668927192688
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 10 época(s).
# Epoch 138/600 | Recon: 0.4906 | Class: 0.2498
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9080247282981873
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 11 época(s).
# Epoch 139/600 | Recon: 0.4802 | Class: 0.2484
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9091355800628662
# Learning Rate atual: 0.000031
# Epoch 140/600 | Recon: 0.4830 | Class: 0.2482
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9095330834388733
# Learning Rate atual: 0.000031
# Epoch 141/600 | Recon: 0.4824 | Class: 0.2478
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9085158109664917
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 142/600 | Recon: 0.4830 | Class: 0.2488
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9076739549636841
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 2 época(s).
# Epoch 143/600 | Recon: 0.4797 | Class: 0.2487
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092407822608948
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 3 época(s).
# Epoch 144/600 | Recon: 0.4838 | Class: 0.2470
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9091121554374695
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 4 época(s).
# Epoch 145/600 | Recon: 0.4800 | Class: 0.2486
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.908048152923584
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 5 época(s).
# Epoch 146/600 | Recon: 0.4825 | Class: 0.2488
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9086912274360657
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 6 época(s).
# Epoch 147/600 | Recon: 0.4789 | Class: 0.2480
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9091121554374695
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 7 época(s).
# Epoch 148/600 | Recon: 0.4771 | Class: 0.2487
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9083404541015625
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 8 época(s).
# Epoch 149/600 | Recon: 0.4797 | Class: 0.2483
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9070308804512024
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 9 época(s).
# Epoch 150/600 | Recon: 0.4818 | Class: 0.2484
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9090069532394409
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 10 época(s).
# Epoch 151/600 | Recon: 0.4777 | Class: 0.2478
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9085041284561157
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 11 época(s).
# Epoch 152/600 | Recon: 0.4797 | Class: 0.2472
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9094629287719727
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 12 época(s).
# Epoch 153/600 | Recon: 0.4763 | Class: 0.2477
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.908819854259491
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 13 época(s).
# Epoch 154/600 | Recon: 0.4790 | Class: 0.2469
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.908796489238739
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 14 época(s).
# Epoch 155/600 | Recon: 0.4746 | Class: 0.2475
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093577265739441
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 15 época(s).
# Epoch 156/600 | Recon: 0.4804 | Class: 0.2463
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9095097184181213
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 16 época(s).
# Epoch 157/600 | Recon: 0.4760 | Class: 0.2477
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9091355800628662
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 17 época(s).
# Epoch 158/600 | Recon: 0.4794 | Class: 0.2479
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9094278812408447
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 18 época(s).
# Epoch 159/600 | Recon: 0.4772 | Class: 0.2464
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093109369277954
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 19 época(s).
# Epoch 160/600 | Recon: 0.4795 | Class: 0.2476
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9085392355918884
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 20 época(s).
# Epoch 161/600 | Recon: 0.4821 | Class: 0.2466
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9083872437477112
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 21 época(s).
# Epoch 162/600 | Recon: 0.4753 | Class: 0.2466
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.910339891910553
# Learning Rate atual: 0.000016
# Epoch 163/600 | Recon: 0.4728 | Class: 0.2470
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096617102622986
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 1 época(s).
# Epoch 164/600 | Recon: 0.4769 | Class: 0.2470
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098254442214966
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 2 época(s).
# Epoch 165/600 | Recon: 0.4742 | Class: 0.2465
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9101528525352478
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 3 época(s).
# Epoch 166/600 | Recon: 0.4753 | Class: 0.2471
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093577265739441
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 4 época(s).
# Epoch 167/600 | Recon: 0.4762 | Class: 0.2467
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9090303182601929
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 5 época(s).
# Epoch 168/600 | Recon: 0.4724 | Class: 0.2457
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9095330834388733
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 6 época(s).
# Epoch 169/600 | Recon: 0.4743 | Class: 0.2460
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096383452415466
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 7 época(s).
# Epoch 170/600 | Recon: 0.4792 | Class: 0.2460
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9089601635932922
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 8 época(s).
# Epoch 171/600 | Recon: 0.4731 | Class: 0.2470
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9099189639091492
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 9 época(s).
# Epoch 172/600 | Recon: 0.4743 | Class: 0.2469
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092875719070435
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 10 época(s).
# Epoch 173/600 | Recon: 0.4772 | Class: 0.2474
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096383452415466
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 11 época(s).
# Epoch 174/600 | Recon: 0.4739 | Class: 0.2467
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.908808171749115
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 12 época(s).
# Epoch 175/600 | Recon: 0.4776 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9101879000663757
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 13 época(s).
# Epoch 176/600 | Recon: 0.4731 | Class: 0.2461
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9089133739471436
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 14 época(s).
# Epoch 177/600 | Recon: 0.4714 | Class: 0.2464
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9102463722229004
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 15 época(s).
# Epoch 178/600 | Recon: 0.4791 | Class: 0.2446
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098721742630005
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 16 época(s).
# Epoch 179/600 | Recon: 0.4721 | Class: 0.2463
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9094278812408447
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 17 época(s).
# Epoch 180/600 | Recon: 0.4734 | Class: 0.2461
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9095097184181213
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 18 época(s).
# Epoch 181/600 | Recon: 0.4774 | Class: 0.2461
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092524647712708
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 19 época(s).
# Epoch 182/600 | Recon: 0.4706 | Class: 0.2452
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.90974360704422
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 20 época(s).
# Epoch 183/600 | Recon: 0.4697 | Class: 0.2467
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9097669720649719
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 21 época(s).
# Epoch 184/600 | Recon: 0.4684 | Class: 0.2461
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093577265739441
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 22 época(s).
# Epoch 185/600 | Recon: 0.4726 | Class: 0.2444
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9099657535552979
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 23 época(s).
# Epoch 186/600 | Recon: 0.4702 | Class: 0.2458
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092057347297668
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 24 época(s).
# Epoch 187/600 | Recon: 0.4712 | Class: 0.2455
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093694090843201
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 25 época(s).
# Epoch 188/600 | Recon: 0.4723 | Class: 0.2459
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098604917526245
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 26 época(s).
# Epoch 189/600 | Recon: 0.4718 | Class: 0.2462
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096733927726746
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 27 época(s).
# Epoch 190/600 | Recon: 0.4717 | Class: 0.2464
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9100008010864258
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 28 época(s).
# Epoch 191/600 | Recon: 0.4745 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9099306464195251
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 29 época(s).
# Epoch 192/600 | Recon: 0.4724 | Class: 0.2456
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098488092422485
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 30 época(s).
# Epoch 193/600 | Recon: 0.4716 | Class: 0.2454
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9097669720649719
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 31 época(s).
# Epoch 194/600 | Recon: 0.4704 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909392774105072
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 32 época(s).
# Epoch 195/600 | Recon: 0.4698 | Class: 0.2460
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096851348876953
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 33 época(s).
# Epoch 196/600 | Recon: 0.4719 | Class: 0.2439
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092174172401428
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 34 época(s).
# Epoch 197/600 | Recon: 0.4747 | Class: 0.2458
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9088432192802429
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 35 época(s).
# Epoch 198/600 | Recon: 0.4712 | Class: 0.2444
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9099072813987732
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 36 época(s).
# Epoch 199/600 | Recon: 0.4699 | Class: 0.2462
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9094980359077454
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 37 época(s).
# Epoch 200/600 | Recon: 0.4733 | Class: 0.2445
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.910141110420227
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 38 época(s).
# Epoch 201/600 | Recon: 0.4705 | Class: 0.2449
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909544825553894
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 39 época(s).
# Epoch 202/600 | Recon: 0.4755 | Class: 0.2445
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9104100465774536
# Learning Rate atual: 0.000002
# Epoch 203/600 | Recon: 0.4718 | Class: 0.2445
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9100475907325745
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 1 época(s).
# Epoch 204/600 | Recon: 0.4724 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9088315367698669
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 2 época(s).
# Epoch 205/600 | Recon: 0.4726 | Class: 0.2458
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9101060628890991
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 3 época(s).
# Epoch 206/600 | Recon: 0.4714 | Class: 0.2459
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093109369277954
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 4 época(s).
# Epoch 207/600 | Recon: 0.4733 | Class: 0.2449
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098137617111206
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 5 época(s).
# Epoch 208/600 | Recon: 0.4703 | Class: 0.2448
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9099891185760498
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 6 época(s).
# Epoch 209/600 | Recon: 0.4713 | Class: 0.2452
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098955988883972
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 7 época(s).
# Epoch 210/600 | Recon: 0.4661 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9106205105781555
# Learning Rate atual: 0.000001
# Epoch 211/600 | Recon: 0.4715 | Class: 0.2458
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9109713435173035
# Learning Rate atual: 0.000001
# Epoch 212/600 | Recon: 0.4711 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9103749990463257
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 1 época(s).
# Epoch 213/600 | Recon: 0.4689 | Class: 0.2444
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9091939926147461
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 2 época(s).
# Epoch 214/600 | Recon: 0.4692 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9094045162200928
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 3 época(s).
# Epoch 215/600 | Recon: 0.4680 | Class: 0.2442
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098604917526245
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 4 época(s).
# Epoch 216/600 | Recon: 0.4718 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9090536832809448
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 5 época(s).
# Epoch 217/600 | Recon: 0.4708 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9087730646133423
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 6 época(s).
# Epoch 218/600 | Recon: 0.4768 | Class: 0.2453
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909755289554596
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 7 época(s).
# Epoch 219/600 | Recon: 0.4698 | Class: 0.2457
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096383452415466
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 8 época(s).
# Epoch 220/600 | Recon: 0.4723 | Class: 0.2453
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9094746708869934
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 9 época(s).
# Epoch 221/600 | Recon: 0.4679 | Class: 0.2446
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096266627311707
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 10 época(s).
# Epoch 222/600 | Recon: 0.4671 | Class: 0.2446
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9100475907325745
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 11 época(s).
# Epoch 223/600 | Recon: 0.4693 | Class: 0.2448
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909591555595398
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 12 época(s).
# Epoch 224/600 | Recon: 0.4753 | Class: 0.2440
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9100592732429504
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 13 época(s).
# Epoch 225/600 | Recon: 0.4718 | Class: 0.2455
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909579873085022
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 14 época(s).
# Epoch 226/600 | Recon: 0.4747 | Class: 0.2449
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9094863533973694
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 15 época(s).
# Epoch 227/600 | Recon: 0.4711 | Class: 0.2456
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909591555595398
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 16 época(s).
# Epoch 228/600 | Recon: 0.4709 | Class: 0.2446
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909381091594696
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 17 época(s).
# Epoch 229/600 | Recon: 0.4698 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.910515308380127
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 18 época(s).
# Epoch 230/600 | Recon: 0.4729 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093460440635681
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 19 época(s).
# Epoch 231/600 | Recon: 0.4706 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9105503559112549
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 20 época(s).
# Epoch 232/600 | Recon: 0.4727 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9096851348876953
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 21 época(s).
# Epoch 233/600 | Recon: 0.4720 | Class: 0.2445
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9085041284561157
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 22 época(s).
# Epoch 234/600 | Recon: 0.4655 | Class: 0.2449
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098604917526245
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 23 época(s).
# Epoch 235/600 | Recon: 0.4902 | Class: 0.2460
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098488092422485
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 24 época(s).
# Epoch 236/600 | Recon: 0.4710 | Class: 0.2447
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9089601635932922
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 25 época(s).
# Epoch 237/600 | Recon: 0.4689 | Class: 0.2456
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098488092422485
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 26 época(s).
# Epoch 238/600 | Recon: 0.4689 | Class: 0.2439
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093226194381714
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 27 época(s).
# Epoch 239/600 | Recon: 0.4730 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9105971455574036
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 28 época(s).
# Epoch 240/600 | Recon: 0.4683 | Class: 0.2440
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.909591555595398
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 29 época(s).
# Epoch 241/600 | Recon: 0.4739 | Class: 0.2451
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9099891185760498
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 30 época(s).
# Epoch 242/600 | Recon: 0.4699 | Class: 0.2448
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098371267318726
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 31 época(s).
# Epoch 243/600 | Recon: 0.4726 | Class: 0.2444
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9101762175559998
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 32 época(s).
# Epoch 244/600 | Recon: 0.4749 | Class: 0.2444
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9101995825767517
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 33 época(s).
# Epoch 245/600 | Recon: 0.4718 | Class: 0.2454
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9088783264160156
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 34 época(s).
# Epoch 246/600 | Recon: 0.4730 | Class: 0.2443
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098488092422485
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 35 época(s).
# Epoch 247/600 | Recon: 0.4727 | Class: 0.2442
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9088900089263916
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 36 época(s).
# Epoch 248/600 | Recon: 0.4718 | Class: 0.2440
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9104334712028503
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 37 época(s).
# Epoch 249/600 | Recon: 0.4721 | Class: 0.2456
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9102346897125244
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 38 época(s).
# Epoch 250/600 | Recon: 0.4723 | Class: 0.2449
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9098721742630005
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 39 época(s).
# Epoch 251/600 | Recon: 0.4725 | Class: 0.2447
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092758893966675
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 40 época(s).
# Epoch 252/600 | Recon: 0.4718 | Class: 0.2454
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9088900089263916
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 41 época(s).
# Epoch 253/600 | Recon: 0.4719 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9093109369277954
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 42 época(s).
# Epoch 254/600 | Recon: 0.4722 | Class: 0.2449
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9100242257118225
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 43 época(s).
# Epoch 255/600 | Recon: 0.4735 | Class: 0.2443
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.910491943359375
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 44 época(s).
# Epoch 256/600 | Recon: 0.4706 | Class: 0.2456
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092290997505188
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 45 época(s).
# Epoch 257/600 | Recon: 0.4730 | Class: 0.2446
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9092875719070435
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 46 época(s).
# Epoch 258/600 | Recon: 0.4691 | Class: 0.2443
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9100475907325745
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 47 época(s).
# Epoch 259/600 | Recon: 0.4698 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9100826382637024
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 48 época(s).
# Epoch 260/600 | Recon: 0.4695 | Class: 0.2450
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9101294279098511
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 49 época(s).
# Epoch 261/600 | Recon: 0.4706 | Class: 0.2449
# Predictions shape: torch.Size([85523])
# Labels shape: torch.Size([85523])
# Acurácia: 0.9090654253959656
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 50 época(s).
# Early stopping ativado na época 261
# Melhor modelo MLP restaurado com base na menor perda de validação.
# Tempo de execução:  319966.5221891403
# Memória usada (MB): 689.2265625

# %%
def testa(target_test, treino, labels_test):
    # Define o modelo para modo de avaliação
    modelo_AE1.eval()
    modelo_AE2.eval()
    modelo_AE3.eval()
    modelo_MLP.eval()
    loss_fn = nn.CrossEntropyLoss()
    
    all_preds, all_labels, all_attacks = [], [], []
    
    # Loop para avaliar os dados de teste
    for (X, y), (z, y2) in zip(target_test, labels_test):
        
        X = X.to(device)
        y = y.squeeze()
        y = y.to(device).float()
        z = z.to(device).float()
        
        # Forward pass para os Autoencoders
        recon1, x_latent1 = modelo_AE1(X)
        recon2, x_latent2 = modelo_AE2(X)
        recon3, x_latent3 = modelo_AE3(X)
        
        # Classificação com vetor latente combinado
        x_latent = torch.cat([x_latent1, x_latent2, x_latent3], dim=1)
        outputs = modelo_MLP(x_latent)
        
        # Calcula a perda de classificação usando CrossEntropyLoss
        loss_class = loss_fn(outputs, y.long().to(device))
        
        # Calcula as previsões (classe com maior probabilidade)
        preds = torch.argmax(outputs, dim=1)
        
        # Adiciona as previsões e rótulos à lista
        all_preds.append(preds.cpu())
        all_labels.append(y.cpu())
        all_attacks.append(z.cpu())
    
    # Concatenando todas as previsões e rótulos
    all_preds_list = torch.cat(all_preds)
    all_labels_list = torch.cat(all_labels)
    all_attacks_list = torch.cat(all_attacks)

    # Cálculo da acurácia geral
    acc = (all_preds_list == all_labels_list).float().mean().item()

    # Matriz de Confusão
    matriz2 = confusion_matrix(all_labels_list.numpy(), all_preds_list.numpy())
    sns.set(rc={"figure.figsize": (8, 6)})
    title = "Matriz de Confusão: " + treino
    sns.heatmap(matriz2 / np.sum(matriz2), annot=True, annot_kws={'size': 10}, fmt='.2%', cmap='Blues').set_title(title)
    plt.show()

    # Cálculo das métricas por classe
    TPR = []  # Sensibilidade (Recall)
    TNR = []  # Especificidade
    ACC_class = []  # Acurácia por classe

    for i in range(matriz2.shape[0]):
      TP = matriz2[i, i]
      FP = matriz2[:, i].sum() - TP
      FN = matriz2[i, :].sum() - TP
      TN = matriz2.sum() - (TP + FP + FN)
 
      # Métricas
      TPR.append(TP / (TP + FN) if (TP + FN) != 0 else 0)
      TNR.append(TN / (TN + FP) if (TN + FP) != 0 else 0)
      ACC_class.append((TP + TN) / (TP + TN + FP + FN) if (TP + TN + FP + FN) != 0 else 0)

    # Médias
    TPR_mean = np.mean(TPR)
    TNR_mean = np.mean(TNR)
    ACC_mean = np.mean(ACC_class)

    # Exibir resultados
    print("\n=== Métricas por Classe ===")
    for i, (tpr, tnr, acc_c) in enumerate(zip(TPR, TNR, ACC_class)):
       print(f"Classe {i}: TPR={tpr:.3f}, TNR={tnr:.3f}, Acc={acc_c:.3f}")

    print("\n=== Médias Gerais ===")
    print(f"Acurácia geral: {acc:.3f}")
    print(f"TPR médio: {TPR_mean:.3f}")
    print(f"TNR médio: {TNR_mean:.3f}")
    print(f"Acurácia média por classe: {ACC_mean:.3f}")
    
    # Cálculo da métrica F1 para multiclasse (micro e macro average)
    F1 = f1_score(all_labels_list.numpy(), all_preds_list.numpy(), average='weighted')  # Usando média ponderada

    return TPR_mean, TNR_mean, F1, acc, all_preds_list.view(-1), all_labels_list.view(-1), all_attacks_list.view(-1)

# %%
datasets = ["dataset1", "dataset2", "dataset3", "dataset4"]
target_test = [loader_test1, loader_test2, loader_test3, loader_test4]
labels_test = [z_split_test1, z_split_test2, z_split_test3, z_split_test4]

TPRs = []
TNRs = []
F1s = []
ACCs = []
all_preds_lists = []
all_labels_lists = []
all_attacks_lists = []

for data, teste, labels  in zip(datasets, target_test, labels_test):
    print(f"Treinando com Ambos e validando com {data}")
    TPR, TNR, F1, acc, all_preds_list, all_labels_list, all_attacks_list = testa(teste, data, labels)
    TPRs.append(TPR)
    TNRs.append(TNR)
    F1s.append(F1)
    ACCs.append(acc)
    all_preds_lists.extend(all_preds_list)
    all_labels_lists.extend(all_labels_list)
    all_attacks_lists.extend(all_attacks_list)
    
# Criação da tabela
df = pd.DataFrame({
    'Dataset': datasets,
    'TPR': TPRs,
    'TNR': TNRs,
    'F1-Score': F1s,
    'Acurácia': ACCs
})
print("----------------------------------------------")
print("Resumo da validação nos Datasets:")
print(df)
print("----------------------------------------------")
# Out:
# Treinando com Ambos e validando com dataset1
# Treinando com Ambos e validando com dataset2
# Treinando com Ambos e validando com dataset3
# Treinando com Ambos e validando com dataset4
# ----------------------------------------------
# Resumo da validação nos Datasets:
#     Dataset       TPR       TNR  F1-Score  Acurácia
# 0  dataset1  0.531762  0.993397  0.959387  0.959527
# 1  dataset2  0.764857  0.986750  0.894863  0.897764
# 2  dataset3  0.526468  0.976820  0.852539  0.870984
# 3  dataset4  0.662330  0.992755  0.885005  0.910555
# ----------------------------------------------

# %%
# Combinar todas as predições em um dataframe para tabulação

all_labels = [t.item() for t in all_labels_lists]
all_preds = [t.item() for t in all_preds_lists]
all_attacks = [t.item() for t in all_attacks_lists]

# Inverter dicionario
map_attacks_inv = {v: k for k, v in map_attacks.items()}

df = pd.DataFrame({
    "Real": all_labels,
    "Previsto": all_preds,
    "Ataque": all_attacks
})

# Criar coluna de acerto/erro
df["Acertou"] = df["Real"] == df["Previsto"]

# Agrupar predições por tipo de ataque
tabela = df.groupby("Ataque").agg(
    Total=("Real","count"),
    Acertos=("Acertou","sum")
)

# Adicionar Acurácia por ataque
tabela["Acurácia"] = tabela["Acertos"] / tabela["Total"]

# Adicionar F1 por ataque
f1_por_ataque = {}
TP_por_ataque = {}
TN_por_ataque = {}
FP_por_ataque = {}
FN_por_ataque = {}

for atk, grupo in df.groupby("Ataque"):
    TP_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 1)).sum()
    TN_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 0)).sum()
    FP_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 1)).sum()
    FN_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 0)).sum()

for atk, grupo in df.groupby("Ataque"):
    f1_por_ataque[atk] = f1_score(
        grupo["Real"], grupo["Previsto"],
        average="weighted",   # ou "macro"
        zero_division=0
    )
    
tabela["TP"] = tabela.index.map(TP_por_ataque)
tabela["TN"] = tabela.index.map(TN_por_ataque)
tabela["FP"] = tabela.index.map(FP_por_ataque)
tabela["FN"] = tabela.index.map(FN_por_ataque)
tabela["F1"] = tabela.index.map(f1_por_ataque)


# Renomear indice pelo nome do ataque
tabela.index = tabela.index.map(map_attacks_inv)

print("Resumo por tipo de ataque:")
print(tabela)
# Out:
# Resumo por tipo de ataque:
#                           Total  Acertos  Acurácia    TP     TN  FP  FN  \
# Ataque
# Benign                    61125    55845  0.913620  3679  29653  28  22
# dos                        8527     8008  0.939135  1016   4167   6   3
# Reconnaissance             7409     6917  0.933594   903   3661   2   0
# ddos                       9825     9166  0.932926  1136   4662  13   4
# Theft                       364      351  0.964286    64    168   1   0
# ransomware                  514      460  0.894942    23    256   1   0
# scanning                   2166     1949  0.899815   139    982   1   1
# xss                        2167     1932  0.891555   132    976   4   0
# mitm                       1158     1017  0.878238    41    534   4   2
# password                   2167     1936  0.893401   135   1001   3   0
# backdoor                   2491     2236  0.897631   142   1136   8   1
# Analysis                    345      296  0.857971     0    171   0   0
# Generic                    2484     2155  0.867552    13   1215   1   1
# Exploits                   4733     4114  0.869216    24   2357   1   0
# Bot                        1650     1493  0.904848     0    813   0   0
# DoS_attacks-SlowHTTPTest   1500     1369  0.912667     0    710   0   0
# SSH-Bruteforce             1650     1507  0.913333     0    837   2   0
# DoS_attacks-Hulk           1500     1363  0.908667     0    755   0   0
# Infilteration              1650     1494  0.905455     0    814   0   0
# DDOS_attack-HOIC           1650     1495  0.906061     0    825   0   0
# FTP-BruteForce             1650     1514  0.917576     0    819   0   0
# Brute_Force_-Web            243      214  0.880658     0    117   0   0
# DDoS_attacks-LOIC-HTTP     1650     1517  0.919394     0    805   0   0
# DoS_attacks-GoldenEye      1500     1382  0.921333     0    748   0   0
# DDOS_attack-LOIC-UDP        517      467  0.903288     0    253   0   0
# DoS_attacks-Slowloris      1500     1391  0.927333     0    761   0   0
# Brute_Force_-XSS             72       66  0.916667     0     43   0   0
# SQL_Injection                66       57  0.863636     0     32   0   0
#
#                                 F1
# Ataque
# Benign                    0.905085
# dos                       0.938450
# Reconnaissance            0.930539
# ddos                      0.931209
# Theft                     0.964032
# ransomware                0.893623
# scanning                  0.896939
# xss                       0.888540
# mitm                      0.876450
# password                  0.887534
# backdoor                  0.896727
# Analysis                  0.834003
# Generic                   0.848195
# Exploits                  0.851578
# Bot                       0.877865
# DoS_attacks-SlowHTTPTest  0.887500
# SSH-Bruteforce            0.889412
# DoS_attacks-Hulk          0.881515
# Infilteration             0.878634
# DDOS_attack-HOIC          0.879763
# FTP-BruteForce            0.893837
# Brute_Force_-Web          0.855322
# DDoS_attacks-LOIC-HTTP    0.892882
# DoS_attacks-GoldenEye     0.896492
# DDOS_attack-LOIC-UDP      0.875075
# DoS_attacks-Slowloris     0.906968
# Brute_Force_-XSS          0.892415
# SQL_Injection             0.839325
