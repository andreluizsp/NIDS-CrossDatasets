# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader, Dataset, ConcatDataset
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

# Calculo de similaridade
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
from scipy.spatial.distance import euclidean
from scipy.spatial.distance import cityblock
from sklearn.metrics import jaccard_score

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns

# Define seed
SEED = 42

# Set the seed for reproducibility
torch.manual_seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)  # For multi-GPU setups
torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
torch.backends.cudnn.benchmark = False    # Disable if you want deterministic results

Feature_ambos = [
                #'L4_SRC_PORT',
                #'L4_DST_PORT',
                'PROTOCOL',
                #'L7_PROTO',
                'IN_BYTES',
                'IN_PKTS',
                'OUT_BYTES',
                'OUT_PKTS',
                #'TCP_FLAGS',
                #'CLIENT_TCP_FLAGS',
                #'SERVER_TCP_FLAGS',
                'FLOW_DURATION_MILLISECONDS',
                'DURATION_IN', 
                'DURATION_OUT',
                #'MIN_TTL', 
                #'MAX_TTL',
                'LONGEST_FLOW_PKT',
                #'SHORTEST_FLOW_PKT',
                #'MIN_IP_PKT_LEN', 
                'MAX_IP_PKT_LEN', 
                'SRC_TO_DST_SECOND_BYTES', 
                'DST_TO_SRC_SECOND_BYTES',
                'RETRANSMITTED_IN_BYTES', 
                'RETRANSMITTED_IN_PKTS', 
                'RETRANSMITTED_OUT_BYTES', 
                'RETRANSMITTED_OUT_PKTS',
                'SRC_TO_DST_AVG_THROUGHPUT', 
                'DST_TO_SRC_AVG_THROUGHPUT', 
                'NUM_PKTS_UP_TO_128_BYTES',
                'NUM_PKTS_128_TO_256_BYTES', 
                'NUM_PKTS_256_TO_512_BYTES', 
                'NUM_PKTS_512_TO_1024_BYTES',
                'NUM_PKTS_1024_TO_1514_BYTES', 
                #'TCP_WIN_MAX_IN', 
                #'TCP_WIN_MAX_OUT', 
                'ICMP_TYPE', 
                'ICMP_IPV4_TYPE',
                #'DNS_QUERY_ID', 
                'DNS_QUERY_TYPE', 
                #'DNS_TTL_ANSWER',
                #'FTP_COMMAND_RET_CODE',
                'Label', 
                'Attack']

Feature_name = [f for f in Feature_ambos if f not in ['Label', 'Attack']]

input_dim = 26

# Mapear todos os ataques
map_attacks = {'Benign':0, 
              'DoS':1,
              'dos':1,
              'Reconnaissance':2,
              'DDoS':3,
              'ddos':3,
              'Theft':4,
              'ransomware':5,
              'scanning':6,
              'xss':7,
              'mitm':8,
              'password':9,
              'Backdoor':10,
              'backdoor':10,
              'Analysis':11,
              'Generic':12,
              'Exploits':13,
              'Bot':14,
              'DoS_attacks-SlowHTTPTest':15,
              'SSH-Bruteforce':16,
              'DoS_attacks-Hulk':17,
              'Infilteration':18,
              'DDOS_attack-HOIC':19, 
              'FTP-BruteForce':20,
              'Brute_Force_-Web':21, 
              'DDoS_attacks-LOIC-HTTP':22, 
              'DoS_attacks-GoldenEye':23,
              'DDOS_attack-LOIC-UDP':24, 
              'DoS_attacks-Slowloris':25, 
              'Brute_Force_-XSS':26,
              'SQL_Injection':27
              }

# %%
class AE(nn.Module):
    def __init__(self, input_dim, latent_dim, dropout_rate):
        super(AE, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(512, 256), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(256, 128), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(128, 64), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(64, 32), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(32, latent_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 32), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(32, 64), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(64, 128), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(128, 256), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(256, 512), 
            nn.PReLU(), nn.Dropout(dropout_rate),
            nn.Linear(512, input_dim)
        )

    def forward(self, x):
        x_enc = self.encoder(x)
        recon = self.decoder(x_enc)
        return recon, x_enc

# %%
def ae_loss(recon_x, x):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    return recon_loss

# %%
class MLP(nn.Module):
    def __init__(self, latent_dim):
        super(MLP, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(latent_dim, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(256, 64),
            nn.ReLU(True),
            nn.Dropout(0.2),

            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.mlp(x)

# %%
def get_datasets(dataset):
    
    if dataset == "dataset1":
         df = pd.read_csv('datasets/dataset1v2.csv') # NF-BoT-IoT-v2
    if dataset == "dataset2":
         df = pd.read_csv('datasets/dataset2v2.csv') # NF-ToN-IoT-v2
    if dataset == "dataset3":
         df = pd.read_csv('datasets/dataset3v2.csv') # NF-UNSW-NB15-v2
    if dataset == "dataset4":
         df = pd.read_csv('datasets/dataset4v2.csv') # NF-CICIDS2018-v3

    dataframe = df[Feature_ambos]
    
    return dataframe

# %%
def preprocessing_data(df):
    df_split = df.copy()
    df_split_label = df_split['Attack']
    df_split = df_split.drop('Attack',axis=1)
    df_split = df_split.drop('Label',axis=1)
    
    # Inicializando o MinMaxScaler (intervalo padrão é [0, 1])
    scaler = MinMaxScaler()

    # Ajustando e transformando os dados
    df_split = scaler.fit_transform(df_split)
    
    df_split_label = df_split_label.to_frame()
    x_split_train, x_split_temp, y_split_train, y_split_temp = train_test_split(df_split, df_split_label, test_size = 0.30, stratify=df_split_label)
    x_split_test, x_split_val, y_split_test, y_split_val = train_test_split(x_split_temp, y_split_temp, test_size = 0.50, stratify=y_split_temp)
    y_split_train['Attack'] = y_split_train['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    z_split_test = y_split_test.copy()
    y_split_test['Attack'] = y_split_test['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    #print(z_split_test)
    z_split_test['Attack']=z_split_test['Attack'].map(map_attacks)
    #z_test = torch.tensor(np.array(z_split_test, dtype=np.float32), dtype = torch.float)
    class_test = torch.tensor(np.array(y_split_test, dtype=np.float32), dtype = torch.float)
    class_attack = torch.tensor(np.array(z_split_test, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(class_attack, class_test)
    z_test = torch.utils.data.DataLoader(dataset, batch_size=100)
    #print(z_split_test)
    y_split_val['Attack'] = y_split_val['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    return x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_test

# %%
def tensor_data(x_source1_train, y_source1_train):
    previsores_train = torch.tensor(np.array(x_source1_train), dtype = torch.float)
    class_train = torch.tensor(np.array(y_source1_train, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(previsores_train, class_train)
    train_loader = torch.utils.data.DataLoader(dataset, batch_size=100, shuffle=True)
    return previsores_train, class_train, dataset, train_loader

# %%
def inicia_datasets(treino):
      df = get_datasets(treino)
      print(f"Prepara {treino}: {df.shape}")
      x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_split_test = preprocessing_data(df)
      print( x_split_train.shape, y_split_train.shape)
      print( x_split_val.shape, y_split_val.shape)
      print( x_split_test.shape, y_split_test.shape)
      dataset_train, class_train, dataset_train, loader_train = tensor_data( x_split_train,  y_split_train)
      dataset_val, class_val, dataset_val, loader_val = tensor_data( x_split_val,  y_split_val)
      dataset_test, class_test, dataset_test, loader_test = tensor_data( x_split_test,  y_split_test)
      return dataset_train, class_train, dataset_train, loader_train, dataset_val, class_val, dataset_val, loader_val, dataset_test, class_test, dataset_test, loader_test, z_split_test

# %%
dataset = "dataset1" 
dataset_train1, class_train1, dataset_train1, loader_train1, dataset_val1, class_val1, dataset_val1, loader_val1, dataset_test1, class_test1, dataset_test1, loader_test1, z_split_test1 = inicia_datasets(dataset)
dataset = "dataset2" 
dataset_train2, class_train2, dataset_train2, loader_train2, dataset_val2, class_val2, dataset_val2, loader_val2, dataset_test2, class_test2, dataset_test2, loader_test2, z_split_test2 = inicia_datasets(dataset)
dataset = "dataset3" 
dataset_train3, class_train3, dataset_train3, loader_train3, dataset_val3, class_val3, dataset_val3, loader_val3, dataset_test3, class_test3, dataset_test3, loader_test3, z_split_test3 = inicia_datasets(dataset)
dataset = "dataset4" 
dataset_train4, class_train4, dataset_train4, loader_train4, dataset_val4, class_val4, dataset_val4, loader_val4, dataset_test4, class_test4, dataset_test4, loader_test4, z_split_test4 = inicia_datasets(dataset)

# Gerar ambos para teste e validação
test_dataset_combined = ConcatDataset([dataset_test1, dataset_test2, dataset_test3, dataset_test4])
test_loader_combined = DataLoader(test_dataset_combined, batch_size=loader_test1.batch_size, shuffle=True)
val_dataset_combined = ConcatDataset([dataset_val1, dataset_val2, dataset_val3, dataset_val4])
val_loader_combined = DataLoader(val_dataset_combined, batch_size=loader_val1.batch_size, shuffle=True)
# Out:
# Prepara dataset1: (224511, 28)
# (157157, 26) (157157, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset2: (224512, 28)
# (157158, 26) (157158, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset3: (142152, 28)
# (99506, 26) (99506, 1)
# (21323, 26) (21323, 1)
# (21323, 26) (21323, 1)
# Prepara dataset4: (223976, 28)
# (156783, 26) (156783, 1)
# (33597, 26) (33597, 1)
# (33596, 26) (33596, 1)

# %%
def treina_modelo(modelo_AE1, modelo_AE2, modelo_MLP, input_dim, device):

    from sklearn.metrics import classification_report
    
    # Hiperparâmetros
    num_classes = 2
    epochs = 600
    lr = 0.001

    Alpha = 1
    Beta = 1
    Gama = 0.7
    
    patience = 50
    best_val_acc = 0
    epochs_no_improve = 0
    best_model_state = None
  
    # Otimizador conjunto
    params = list(modelo_MLP.parameters()) + list(modelo_AE1.parameters()) + list(modelo_AE2.parameters())    
    optimizer = torch.optim.Adam(params, lr=lr)

    # Scheduler: reduz o learning rate se a acurácia parar de melhorar
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=10, factor=0.5)

    # Funções de perda
    class_loss_fn = nn.BCEWithLogitsLoss()

    # Histórico
    loss_vals = []
    loss_valsAE = []
    loss_valsAE2 = []
    loss_valsMLP = []
    val_simC = []
    val_distE = []
    val_distM = []
    val_accuracies = []
    val_losses = []
    
    
    for epoch in range(epochs):
        
        modelo_AE1.train()
        modelo_AE2.train()
        modelo_MLP.train()
        
        sum_loss_recon = 0.0
        sum_loss_class = 0.0
        n_batches = 0
        epoch_loss_val = []
        epoch_simC = []
        epoch_corr = []
        epoch_distE = []
        epoch_distM = []
        epoch_simJ = []
        
        # Variaveis para similaridade
        simC = 0  # Cosseno 
        corr = 0  # Pearson 1.0 Correlação perfeita
        distE = 0  #  Eculidiana - Distância euclidiana
        distM = 0  # Distância de Manhattan
        simJ = 0  # Similaridade de Jaccard (para vetores binários ou conjuntos)

        for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_train1, loader_train2, loader_train3, loader_train4):
    
            X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
            y = torch.cat([y1, y2, y3, y4], dim=0).to(device).float()
            y = y.view(-1, 1)
            
            optimizer.zero_grad()
            
            # Forward do VAE1
            recon1, x_latent1 = modelo_AE1(X)
            
            # Forward do VAE2
            recon2, x_latent2 = modelo_AE2(X)

            # Perda de reconstrução (VAE1)
            recon_loss1 = ae_loss(recon1, X)
            
            # Perda de reconstrução (VAE2)
            recon_loss2 = ae_loss(recon2, X)
            
            # Cálculo das dissimilaridades
            loss_diss = 1 - F.cosine_similarity(x_latent1, x_latent2).mean()
            simC = loss_diss
            
            # Classificação com vetor latente
            x_latent = torch.cat([x_latent1, x_latent2], dim=1)
            outputs = modelo_MLP(x_latent)
            loss_class = F.binary_cross_entropy(outputs, y)

            # Perda total
            loss_recon = (recon_loss1 + recon_loss2)/2

            total_loss =  ( loss_recon * Alpha ) + ( loss_class * Beta ) + ( loss_diss * Gama )

            total_loss.backward()
            optimizer.step()

            sum_loss_recon += (recon_loss1.item() + recon_loss2.item()) / 2
            sum_loss_class += loss_class.item()
            n_batches += 1
            
            torch.cuda.empty_cache()
       
        # === Logs da época ===
        loss_epoch_recon = sum_loss_recon / n_batches
        loss_epoch_class = sum_loss_class / n_batches
        
        loss_valsAE.append(loss_epoch_recon)
        loss_valsMLP.append(loss_epoch_class)
        
        print(f"Epoch {epoch+1:02d}/{epochs} | Recon: {loss_epoch_recon:.4f} | Class: {loss_epoch_class:.4f} | Diss: {simC:.4f}")
        # Mostrar a simialridade da útlima instancia por época
        #print(f"Similaridade Média mu1, mu2 - Cosseno: {np.mean(simC)} | Euclidiana: {distE} | Manhattan: {distM}")
        modelo_AE1.eval()
        modelo_AE2.eval()
        modelo_MLP.eval()
        all_preds, all_labels = [], []
        
        with torch.no_grad():
            
           for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_val1, loader_val2, loader_val3, loader_val4):
    
               X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
               y = torch.cat([y1, y2, y3, y4], dim=0).to(device).float()
               y = y.view(-1, 1)
            
               optimizer.zero_grad()
            
               # Forward do VAE1, VAE2 e VAE3
               recon1, x_latent1 = modelo_AE1(X)
               recon2, x_latent2 = modelo_AE2(X)
            
               # Classificação com vetor latente
               x_latent = torch.cat([x_latent1, x_latent2], dim=1)
               outputs = modelo_MLP(x_latent)
               loss_class = F.binary_cross_entropy(outputs, y)
               
               preds = (outputs > 0.5).float()

               # Calcula loss (BCE para binário)
               loss = F.binary_cross_entropy(outputs, y)
               
               epoch_loss_val.append(loss.item())
               
               all_preds.append(preds.cpu())
               all_labels.append(y.cpu())

        all_preds_list = torch.cat(all_preds)
        all_labels_list = torch.cat(all_labels)
        acc = (all_preds_list.view(-1) == all_labels_list.view(-1)).float().mean().item()
        loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
    
        val_accuracies.append(acc)
        val_losses.append(loss_val)
        print(f"Acurácia: {acc}")

        # Atualiza scheduler com base na acurácia de validação
        scheduler.step(acc)

        # Mostra o learning rate atual
        for param_group in optimizer.param_groups:
            current_lr = param_group['lr']
        print(f"Learning Rate atual: {current_lr:.6f}")        

        # Early stopping
        if acc > best_val_acc:
            best_val_acc = acc
            epochs_no_improve = 0
            best_model_state = modelo_MLP.state_dict()
        else:
            epochs_no_improve += 1
            print(f"Sem melhoria na validação por {epochs_no_improve} época(s).")
            if epochs_no_improve >= patience:
                print(f"Early stopping ativado na época {epoch+1}")
                break

    # Restaurar melhor modelo
    if best_model_state is not None:
        modelo_MLP.load_state_dict(best_model_state)
        print("Melhor modelo MLP restaurado com base na menor perda de validação.")  
    
    return  all_preds, all_labels

# %%
# Instanciando o modelo
latent_dim = 16
input_dim = 26
modelo_AE1 = AE(input_dim, latent_dim, 0.1)
modelo_AE2 = AE(input_dim, latent_dim, 0.2)
latent_dim = 32
modelo_MLP = MLP(latent_dim)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import time 

start = time.time()
train_preds, train_labels = treina_modelo(modelo_AE1, modelo_AE2, modelo_MLP, input_dim, device)
end = time.time()
tempo = end - start
print("Tempo de execução: ", tempo)

import psutil
import os

process = psutil.Process(os.getpid())
print("Memória usada (MB):", process.memory_info().rss / 1024**2)
# Out:
# Epoch 01/600 | Recon: 28.2863 | Class: 0.6029 | Diss: 0.1209
# Acurácia: 0.6820036768913269
# Learning Rate atual: 0.001000
# Epoch 02/600 | Recon: 8.8228 | Class: 0.5620 | Diss: 0.0866
# Acurácia: 0.6903288960456848
# Learning Rate atual: 0.001000
# Epoch 03/600 | Recon: 6.8438 | Class: 0.5450 | Diss: 0.0773
# Acurácia: 0.6987009048461914
# Learning Rate atual: 0.001000
# Epoch 04/600 | Recon: 5.4221 | Class: 0.5172 | Diss: 0.0812
# Acurácia: 0.7447587251663208
# Learning Rate atual: 0.001000
# Epoch 05/600 | Recon: 4.8708 | Class: 0.4968 | Diss: 0.0656
# Acurácia: 0.7436011433601379
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 06/600 | Recon: 4.5270 | Class: 0.4801 | Diss: 0.0588
# Acurácia: 0.7879050374031067
# Learning Rate atual: 0.001000
# Epoch 07/600 | Recon: 4.2905 | Class: 0.4622 | Diss: 0.0609
# Acurácia: 0.7828771471977234
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 08/600 | Recon: 4.1676 | Class: 0.4544 | Diss: 0.0525
# Acurácia: 0.7915414571762085
# Learning Rate atual: 0.001000
# Epoch 09/600 | Recon: 3.9998 | Class: 0.4453 | Diss: 0.0531
# Acurácia: 0.7975398302078247
# Learning Rate atual: 0.001000
# Epoch 10/600 | Recon: 3.8612 | Class: 0.4405 | Diss: 0.0487
# Acurácia: 0.8095833659172058
# Learning Rate atual: 0.001000
# Epoch 11/600 | Recon: 3.7215 | Class: 0.4355 | Diss: 0.0488
# Acurácia: 0.8082854747772217
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 12/600 | Recon: 3.6669 | Class: 0.4287 | Diss: 0.0441
# Acurácia: 0.8285022974014282
# Learning Rate atual: 0.001000
# Epoch 13/600 | Recon: 3.5063 | Class: 0.4176 | Diss: 0.0553
# Acurácia: 0.8290635347366333
# Learning Rate atual: 0.001000
# Epoch 14/600 | Recon: 3.3957 | Class: 0.4068 | Diss: 0.0517
# Acurácia: 0.8302211165428162
# Learning Rate atual: 0.001000
# Epoch 15/600 | Recon: 3.2839 | Class: 0.4044 | Diss: 0.0595
# Acurácia: 0.8252049088478088
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 16/600 | Recon: 3.2179 | Class: 0.4022 | Diss: 0.0528
# Acurácia: 0.81406170129776
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 17/600 | Recon: 3.2389 | Class: 0.4004 | Diss: 0.0528
# Acurácia: 0.8322088718414307
# Learning Rate atual: 0.001000
# Epoch 18/600 | Recon: 3.1293 | Class: 0.3948 | Diss: 0.0464
# Acurácia: 0.8336704969406128
# Learning Rate atual: 0.001000
# Epoch 19/600 | Recon: 3.1000 | Class: 0.3934 | Diss: 0.0562
# Acurácia: 0.8321738243103027
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 20/600 | Recon: 3.0081 | Class: 0.3897 | Diss: 0.0758
# Acurácia: 0.8346176147460938
# Learning Rate atual: 0.001000
# Epoch 21/600 | Recon: 2.9847 | Class: 0.3918 | Diss: 0.0506
# Acurácia: 0.8343486785888672
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 11 época(s).
# Epoch 133/600 | Recon: 1.6865 | Class: 0.2653 | Diss: 0.0316
# Acurácia: 0.8996995091438293
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 12 época(s).
# Epoch 134/600 | Recon: 1.6570 | Class: 0.2616 | Diss: 0.0269
# Acurácia: 0.904645562171936
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 13 época(s).
# Epoch 135/600 | Recon: 1.6333 | Class: 0.2599 | Diss: 0.0289
# Acurácia: 0.9052652716636658
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 14 época(s).
# Epoch 136/600 | Recon: 1.6384 | Class: 0.2591 | Diss: 0.0303
# Acurácia: 0.9042012095451355
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 15 época(s).
# Epoch 137/600 | Recon: 1.6309 | Class: 0.2609 | Diss: 0.0276
# Acurácia: 0.9030904173851013
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 16 época(s).
# Epoch 138/600 | Recon: 1.6069 | Class: 0.2633 | Diss: 0.0302
# Acurácia: 0.8992902636528015
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 17 época(s).
# Epoch 139/600 | Recon: 1.5886 | Class: 0.2605 | Diss: 0.0253
# Acurácia: 0.9043298363685608
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 18 época(s).
# Epoch 140/600 | Recon: 1.6170 | Class: 0.2614 | Diss: 0.0206
# Acurácia: 0.9045519828796387
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 19 época(s).
# Epoch 141/600 | Recon: 1.5759 | Class: 0.2590 | Diss: 0.0248
# Acurácia: 0.9047858715057373
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 20 época(s).
# Epoch 142/600 | Recon: 1.6645 | Class: 0.2585 | Diss: 0.0291
# Acurácia: 0.9055926203727722
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 21 época(s).
# Epoch 143/600 | Recon: 1.5913 | Class: 0.2564 | Diss: 0.0290
# Acurácia: 0.905428946018219
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 22 época(s).
# Epoch 144/600 | Recon: 1.5388 | Class: 0.2547 | Diss: 0.0264
# Acurácia: 0.9070776104927063
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 23 época(s).
# Epoch 145/600 | Recon: 1.5198 | Class: 0.2523 | Diss: 0.0224
# Acurácia: 0.9065748453140259
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 24 época(s).
# Epoch 146/600 | Recon: 1.5217 | Class: 0.2538 | Diss: 0.0259
# Acurácia: 0.9066216349601746
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 25 época(s).
# Epoch 147/600 | Recon: 1.5164 | Class: 0.2526 | Diss: 0.0237
# Acurácia: 0.9063877463340759
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 26 época(s).
# Epoch 148/600 | Recon: 1.4986 | Class: 0.2523 | Diss: 0.0235
# Acurácia: 0.9064345359802246
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 27 época(s).
# Epoch 149/600 | Recon: 1.4992 | Class: 0.2529 | Diss: 0.0215
# Acurácia: 0.9073231816291809
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 28 época(s).
# Epoch 150/600 | Recon: 1.5093 | Class: 0.2509 | Diss: 0.0215
# Acurácia: 0.9074167013168335
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 29 época(s).
# Epoch 151/600 | Recon: 1.5014 | Class: 0.2519 | Diss: 0.0242
# Acurácia: 0.9065163731575012
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 30 época(s).
# Epoch 152/600 | Recon: 1.5122 | Class: 0.2506 | Diss: 0.0224
# Acurácia: 0.9070659279823303
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 31 época(s).
# Epoch 153/600 | Recon: 1.4901 | Class: 0.2511 | Diss: 0.0221
# Acurácia: 0.9115091562271118
# Learning Rate atual: 0.000125
# Epoch 154/600 | Recon: 1.5017 | Class: 0.2504 | Diss: 0.0263
# Acurácia: 0.9131461977958679
# Learning Rate atual: 0.000125
# Epoch 155/600 | Recon: 1.5015 | Class: 0.2498 | Diss: 0.0246
# Acurácia: 0.9069022536277771
# Learning Rate atual: 0.000125
# Sem melhoria na validação por
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 9 época(s).
# Epoch 199/600 | Recon: 1.4136 | Class: 0.2415 | Diss: 0.0208
# Acurácia: 0.9131227731704712
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 10 época(s).
# Epoch 200/600 | Recon: 1.3987 | Class: 0.2414 | Diss: 0.0237
# Acurácia: 0.9146896004676819
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 11 época(s).
# Epoch 201/600 | Recon: 1.3842 | Class: 0.2400 | Diss: 0.0207
# Acurácia: 0.912947416305542
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 12 época(s).
# Epoch 202/600 | Recon: 1.3754 | Class: 0.2401 | Diss: 0.0227
# Acurácia: 0.913695752620697
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 13 época(s).
# Epoch 203/600 | Recon: 1.3751 | Class: 0.2390 | Diss: 0.0230
# Acurácia: 0.9136255979537964
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 14 época(s).
# Epoch 204/600 | Recon: 1.3804 | Class: 0.2387 | Diss: 0.0184
# Acurácia: 0.9147247076034546
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 15 época(s).
# Epoch 205/600 | Recon: 1.3732 | Class: 0.2395 | Diss: 0.0229
# Acurácia: 0.912199079990387
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 16 época(s).
# Epoch 206/600 | Recon: 1.3742 | Class: 0.2395 | Diss: 0.0267
# Acurácia: 0.914455771446228
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 17 época(s).
# Epoch 207/600 | Recon: 1.3735 | Class: 0.2398 | Diss: 0.0254
# Acurácia: 0.9139529466629028
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 18 época(s).
# Epoch 208/600 | Recon: 1.3758 | Class: 0.2403 | Diss: 0.0202
# Acurácia: 0.9132981896400452
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 19 época(s).
# Epoch 209/600 | Recon: 1.3729 | Class: 0.2396 | Diss: 0.0265
# Acurácia: 0.913707435131073
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 20 época(s).
# Epoch 210/600 | Recon: 1.3774 | Class: 0.2401 | Diss: 0.0204
# Acurácia: 0.9136138558387756
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 21 época(s).
# Epoch 211/600 | Recon: 1.3689 | Class: 0.2403 | Diss: 0.0227
# Acurácia: 0.9129824638366699
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 22 época(s).
# Epoch 212/600 | Recon: 1.3722 | Class: 0.2379 | Diss: 0.0226
# Acurácia: 0.9158471822738647
# Learning Rate atual: 0.000016
# Epoch 213/600 | Recon: 1.3542 | Class: 0.2378 | Diss: 0.0228
# Acurácia: 0.9126901626586914
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 1 época(s).
# Epoch 214/600 | Recon: 1.3512 | Class: 0.2387 | Diss: 0.0209
# Acurácia: 0.9155548810958862
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 2 época(s).
# Epoch 215/600 | Recon: 1.3616 | Class: 0.2396 | Diss: 0.0206
# Acurácia: 0.9125498533248901
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 3 época(s).
# Epoch 216/600 | Recon: 1.3518 | Class: 0.2388 | Diss: 0.0210
# Acurácia: 0.9147597551345825
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 4 época(s).
# Epoch 217/600 | Recon: 1.3671 | Class: 0.2385 | Diss: 0.0249
# Acurácia: 0.9138360619544983
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 5 época(s).
# Epoch 218/600 | Recon: 1.3596 | Class: 0.2378 | Diss: 0.0206
# Acurácia: 0.9133098721504211
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 6 época(s).
# Epoch 219/600 | Recon: 1.3565 | Class: 0.2389 | Diss: 0.0238
# Acurácia: 0.9157068729400635
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 7 época(s).
# Epoch 220/600 | Recon: 1.3683 | Class: 0.2393 | Diss: 0.0278
# Acurácia: 0.9168527722358704
# Learning Rate atual: 0.000016
# Epoch 221/600 | Recon: 1.3994 | Class: 0.2386 | Diss: 0.0194
# Acurácia: 0.9136138558387756
# Learning Rate atual: 0.000016
# Sem melhoria na validação por
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 20 época(s).
# Epoch 243/600 | Recon: 1.3522 | Class: 0.2386 | Diss: 0.0208
# Acurácia: 0.9163265824317932
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 21 época(s).
# Epoch 244/600 | Recon: 1.3504 | Class: 0.2385 | Diss: 0.0256
# Acurácia: 0.9175075888633728
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 22 época(s).
# Epoch 245/600 | Recon: 1.3480 | Class: 0.2373 | Diss: 0.0297
# Acurácia: 0.9157419800758362
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 23 época(s).
# Epoch 246/600 | Recon: 1.3480 | Class: 0.2380 | Diss: 0.0174
# Acurácia: 0.9165136814117432
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 24 época(s).
# Epoch 247/600 | Recon: 1.3545 | Class: 0.2372 | Diss: 0.0225
# Acurácia: 0.9163032174110413
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 25 época(s).
# Epoch 248/600 | Recon: 1.3514 | Class: 0.2383 | Diss: 0.0194
# Acurácia: 0.9163850545883179
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 26 época(s).
# Epoch 249/600 | Recon: 1.3493 | Class: 0.2376 | Diss: 0.0167
# Acurácia: 0.9157770276069641
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 27 época(s).
# Epoch 250/600 | Recon: 1.3508 | Class: 0.2374 | Diss: 0.0207
# Acurácia: 0.9154496192932129
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 28 época(s).
# Epoch 251/600 | Recon: 1.3597 | Class: 0.2376 | Diss: 0.0186
# Acurácia: 0.9166656732559204
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 29 época(s).
# Epoch 252/600 | Recon: 1.3540 | Class: 0.2381 | Diss: 0.0202
# Acurácia: 0.916911244392395
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 30 época(s).
# Epoch 253/600 | Recon: 1.3430 | Class: 0.2372 | Diss: 0.0269
# Acurácia: 0.9165838360786438
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 31 época(s).
# Epoch 254/600 | Recon: 1.3380 | Class: 0.2373 | Diss: 0.0181
# Acurácia: 0.9167709350585938
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 32 época(s).
# Epoch 255/600 | Recon: 1.3488 | Class: 0.2378 | Diss: 0.0240
# Acurácia: 0.9171801805496216
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 33 época(s).
# Epoch 256/600 | Recon: 1.3582 | Class: 0.2387 | Diss: 0.0220
# Acurácia: 0.9165955185890198
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 34 época(s).
# Epoch 257/600 | Recon: 1.3540 | Class: 0.2366 | Diss: 0.0167
# Acurácia: 0.9177414178848267
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 35 época(s).
# Epoch 258/600 | Recon: 1.3503 | Class: 0.2367 | Diss: 0.0227
# Acurácia: 0.9162096977233887
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 36 época(s).
# Epoch 259/600 | Recon: 1.3570 | Class: 0.2384 | Diss: 0.0235
# Acurácia: 0.9167826175689697
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 37 época(s).
# Epoch 260/600 | Recon: 1.3478 | Class: 0.2373 | Diss: 0.0194
# Acurácia: 0.9178466796875
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 38 época(s).
# Epoch 261/600 | Recon: 1.3618 | Class: 0.2371 | Diss: 0.0234
# Acurácia: 0.917694628238678
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 39 época(s).
# Epoch 262/600 | Recon: 1.3478 | Class: 0.2371 | Diss: 0.0238
# Acurácia: 0.9158354997634888
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 40 época(s).
# Epoch 263/600 | Recon: 1.3609 | Class: 0.2375 | Diss: 0.0223
# Acurácia: 0.917098343372345
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 41 época(s).
# Epoch 264/600 | Recon: 1.3386 | Class: 0.2379 | Diss: 0.0195
# Acurácia: 0.9171801805496216
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 42 época(s).
# Epoch 265/600 | Recon: 1.3525 | Class: 0.2384 | Diss: 0.0288
# Acurácia: 0.9159173369407654
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 43 época(s).
# Epoch 266/600 | Recon: 1.3403 | Class: 0.2377 | Diss: 0.0190
# Acurácia: 0.915414571762085
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 44 época(s).
# Epoch 267/600 | Recon: 1.3377 | Class: 0.2372 | Diss: 0.0261
# Acurácia: 0.9168059825897217
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 45 época(s).
# Epoch 268/600 | Recon: 1.3364 | Class: 0.2380 | Diss: 0.0216
# Acurácia: 0.9156718254089355
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 46 época(s).
# Epoch 269/600 | Recon: 1.3291 | Class: 0.2376 | Diss: 0.0146
# Acurácia: 0.9163148999214172
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 47 época(s).
# Epoch 270/600 | Recon: 1.3416 | Class: 0.2371 | Diss: 0.0234
# Acurácia: 0.9156367182731628
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 48 época(s).
# Epoch 271/600 | Recon: 1.3512 | Class: 0.2371 | Diss: 0.0189
# Acurácia: 0.9161161184310913
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 49 época(s).
# Epoch 272/600 | Recon: 1.3416 | Class: 0.2374 | Diss: 0.0238
# Acurácia: 0.9161161184310913
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 50 época(s).
# Early stopping ativado na época 272
# Melhor modelo MLP restaurado com base na menor perda de validação.
# Tempo de execução:  295889.47457027435
# Memória usada (MB): 690.8671875

# %%
def testa(target_test, treino, labels_test):
  # Valida source
  modelo_AE1.eval()
  modelo_AE2.eval()
  modelo_MLP.eval()
  all_preds, all_labels, all_attacks = [], [], []

  with torch.no_grad():
      
    for (X, y), (z, y2) in zip(target_test, labels_test):

         X = X.to(device)
         y = y.to(device).float()
         y = y.view(-1, 1)
         z = z.to(device).float()
         z = z.view(-1, 1)
            
         # Forward do VAE1, VAE2
         recon1, x_latent1 = modelo_AE1(X)
         recon2, x_latent2 = modelo_AE2(X)
            
         # Classificação com vetor latente
         x_latent = torch.cat([x_latent1, x_latent2], dim=1)
         outputs = modelo_MLP(x_latent)
         loss_class = F.binary_cross_entropy(outputs, y)
               
         preds = (outputs > 0.5).float()

         # Calcula loss (BCE para binário)
         loss = F.binary_cross_entropy(outputs, y)
               
         all_preds.append(preds.cpu())
         all_labels.append(y.cpu())
         all_attacks.append(z.cpu())
        
  all_preds_list = torch.cat(all_preds)
  all_labels_list = torch.cat(all_labels)
  all_attacks_list = torch.cat(all_attacks)

  acc = (all_preds_list.view(-1) == all_labels_list.view(-1)).float().mean().item()

  # Matriz de confusão
  matriz2 = confusion_matrix(all_preds_list.numpy().round(), all_labels_list.numpy().round())
  sns.set(rc={"figure.figsize": (6, 6)})
  title = "Matriz de Confusão: " + treino
  sns.heatmap(matriz2/np.sum(matriz2), annot=True, annot_kws={'size': 10}, fmt='.2%', cmap='Blues').set_title(title)
  plt.show()

  # Extração dos elementos da matriz (para problema binário)
  TN, FP, FN, TP = matriz2.ravel()

  # Cálculo das métricas
  TPR = TP / (TP + FN) if (TP + FN) != 0 else 0  # Sensibilidade, Recall
  TNR = TN / (TN + FP) if (TN + FP) != 0 else 0  # Especificidade
  F1 = f1_score(all_labels_list.detach().numpy().round(), all_preds_list.detach().numpy().round())
  return TPR, TNR, F1, acc, all_preds_list.view(-1), all_labels_list.view(-1), all_attacks_list.view(-1)

# %%
datasets = ["dataset1", "dataset2", "dataset3", "dataset4"]
target_test = [loader_test1, loader_test2, loader_test3, loader_test4]
labels_test = [z_split_test1, z_split_test2, z_split_test3, z_split_test4]

TPRs = []
TNRs = []
F1s = []
ACCs = []
all_preds_lists = []
all_labels_lists = []
all_attacks_lists = []

for data, teste, labels  in zip(datasets, target_test, labels_test):
    print(f"Treinando com Ambos e validando com {data}")
    TPR, TNR, F1, acc, all_preds_list, all_labels_list, all_attacks_list = testa(teste, data, labels)
    TPRs.append(TPR)
    TNRs.append(TNR)
    F1s.append(F1)
    ACCs.append(acc)
    all_preds_lists.extend(all_preds_list)
    all_labels_lists.extend(all_labels_list)
    all_attacks_lists.extend(all_attacks_list)
    
# Criação da tabela
df = pd.DataFrame({
    'Dataset': datasets,
    'TPR': TPRs,
    'TNR': TNRs,
    'F1-Score': F1s,
    'Acurácia': ACCs
})
print("----------------------------------------------")
print("Resumo da validação nos Datasets:")
print(df)
print("----------------------------------------------")
# Out:
# Treinando com Ambos e validando com dataset1
# Treinando com Ambos e validando com dataset2
# Treinando com Ambos e validando com dataset3
# Treinando com Ambos e validando com dataset4
# ----------------------------------------------
# Resumo da validação nos Datasets:
#     Dataset       TPR       TNR  F1-Score  Acurácia
# 0  dataset1  0.975292  0.821944  0.871505  0.883867
# 1  dataset2  0.882122  0.816972  0.839017  0.846512
# 2  dataset3  0.977206  0.972165  0.974636  0.974675
# 3  dataset4  0.993613  0.922801  0.953681  0.955471
# ----------------------------------------------

# %%
# Combinar todas as predições em um dataframe para tabulação

all_labels = [t.item() for t in all_labels_lists]
all_preds = [t.item() for t in all_preds_lists]
all_attacks = [t.item() for t in all_attacks_lists]

# Inverter dicionario
map_attacks_inv = {v: k for k, v in map_attacks.items()}

df = pd.DataFrame({
    "Real": all_labels,
    "Previsto": all_preds,
    "Ataque": all_attacks
})

# Criar coluna de acerto/erro
df["Acertou"] = df["Real"] == df["Previsto"]

# Agrupar predições por tipo de ataque
tabela = df.groupby("Ataque").agg(
    Total=("Real","count"),
    Acertos=("Acertou","sum")
)

# Adicionar Acurácia por ataque
tabela["Acurácia"] = tabela["Acertos"] / tabela["Total"]

# Adicionar F1 por ataque
f1_por_ataque = {}
TP_por_ataque = {}
TN_por_ataque = {}
FP_por_ataque = {}
FN_por_ataque = {}
for atk, grupo in df.groupby("Ataque"):
    f1_por_ataque[atk] = f1_score(grupo["Real"], grupo["Previsto"], zero_division=0)
    TP_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 1)).sum()
    TN_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 0)).sum()
    FP_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 1)).sum()
    FN_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 0)).sum()

tabela["TP"] = tabela.index.map(TP_por_ataque)
tabela["TN"] = tabela.index.map(TN_por_ataque)
tabela["FP"] = tabela.index.map(FP_por_ataque)
tabela["FN"] = tabela.index.map(FN_por_ataque)
tabela["F1"] = tabela.index.map(f1_por_ataque)


# Renomear indice pelo nome do ataque
tabela.index = tabela.index.map(map_attacks_inv)

print("Resumo por tipo de ataque:")
print(tabela)
# Out:
# Resumo por tipo de ataque:
#                           Total  Acertos  Acurácia     TP     TN    FP    FN  \
# Ataque
# Benign                    61125    55636  0.910200  26359  29277  1212  4277
# dos                        8527     7538  0.884015   3431   4107   168   821
# Reconnaissance             7409     6700  0.904306   3090   3610    72   637
# ddos                       9825     8489  0.864020   3867   4622   310  1026
# Theft                       364      331  0.909341    152    179     2    31
# ransomware                  514      430  0.836576    184    246    29    55
# scanning                   2166     1802  0.831948    880    922   126   238
# xss                        2167     1842  0.850023    881    961   111   214
# mitm                       1158      959  0.828152    444    515    58   141
# password                   2167     1844  0.850946    854    990   122   201
# backdoor                   2491     2168  0.870333   1013   1155   113   210
# Analysis                    345      340  0.985507    173    167     3     2
# Generic                    2484     2422  0.975040   1193   1229    30    32
# Exploits                   4733     4601  0.972111   2311   2290    68    64
# Bot                        1650     1582  0.958788    753    829     3    65
# DoS_attacks-SlowHTTPTest   1500     1435  0.956667    688    747     6    59
# SSH-Bruteforce             1650     1587  0.961818    790    797     3    60
# DoS_attacks-Hulk           1500     1438  0.958667    692    746     4    58
# Infilteration              1650     1570  0.951515    754    816     6    74
# DDOS_attack-HOIC           1650     1573  0.953333    736    837     4    73
# FTP-BruteForce             1650     1585  0.960606    756    829     5    60
# Brute_Force_-Web            243      229  0.942387    118    111     1    13
# DDoS_attacks-LOIC-HTTP     1650     1578  0.956364    731    847     6    66
# DoS_attacks-GoldenEye      1500     1414  0.942667    685    729     8    78
# DDOS_attack-LOIC-UDP        517      497  0.961315    240    257     1    19
# DoS_attacks-Slowloris      1500     1436  0.957333    681    755     6    58
# Brute_Force_-XSS             72       70  0.972222     34     36     0     2
# SQL_Injection                66       61  0.924242     19     42     0     5
#
#                                 F1
# Ataque
# Benign                    0.905699
# dos                       0.874029
# Reconnaissance            0.897082
# ddos                      0.852701
# Theft                     0.902077
# ransomware                0.814159
# scanning                  0.828625
# xss                       0.844274
# mitm                      0.816927
# password                  0.840965
# backdoor                  0.862495
# Analysis                  0.985755
# Generic                   0.974673
# Exploits                  0.972234
# Bot                       0.956798
# DoS_attacks-SlowHTTPTest  0.954892
# SSH-Bruteforce            0.961656
# DoS_attacks-Hulk          0.957123
# Infilteration             0.949622
# DDOS_attack-HOIC          0.950291
# FTP-BruteForce            0.958782
# Brute_Force_-Web          0.944000
# DDoS_attacks-LOIC-HTTP    0.953064
# DoS_attacks-GoldenEye     0.940934
# DDOS_attack-LOIC-UDP      0.960000
# DoS_attacks-Slowloris     0.955119
# Brute_Force_-XSS          0.971429
# SQL_Injection             0.883721
